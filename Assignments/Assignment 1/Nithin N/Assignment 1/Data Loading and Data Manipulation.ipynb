# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
file = pd.read_csv("vgchartz-2024.csv")

# %%
#Now to read the first 5 entries using head

# %%
file.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  na_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4      6.37
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7      6.06
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6      8.41
# 3    X360   Action  Rockstar Games  Rockstar North           NaN      9.06
# 4     PS4  Shooter      Activision        Treyarch           8.1      6.18
#
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   na_sales      12637 non-null  float64
#  8   jp_sales      6726 non-null   float64
#  9   pal_sales     12824 non-null  float64
#  10  other_sales   15128 non-null  float64
#  11  release_date  56965 non-null  object
#  12  last_update   17879 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 6.3+ MB

# %%
file.describe()
# Out:
#        critic_score      na_sales     jp_sales     pal_sales   other_sales
# count   6678.000000  12637.000000  6726.000000  12824.000000  15128.000000
# mean       7.220440      0.264740     0.102281      0.149472      0.043041
# std        1.457066      0.494787     0.168811      0.392653      0.126643
# min        1.000000      0.000000     0.000000      0.000000      0.000000
# 25%        6.400000      0.050000     0.020000      0.010000      0.000000
# 50%        7.500000      0.120000     0.040000      0.040000      0.010000
# 75%        8.300000      0.280000     0.120000      0.140000      0.030000
# max       10.000000      9.760000     2.130000      9.850000      3.120000

# %%
file.dtypes
# Out:
# img              object
# title            object
# console          object
# genre            object
# publisher        object
# developer        object
# critic_score    float64
# na_sales        float64
# jp_sales        float64
# pal_sales       float64
# other_sales     float64
# release_date     object
# last_update      object
# dtype: object

# %%
file.columns
# Out:
# Index(['img', 'title', 'console', 'genre', 'publisher', 'developer',
#        'critic_score', 'na_sales', 'jp_sales', 'pal_sales', 'other_sales',
#        'release_date', 'last_update'],
#       dtype='object')

# %%
The things below show what are all missing.

# %%
file.isnull().sum()
# Out:
# img                 0
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
missing_developers = file[file['developer'].isnull()]
missing_developers
# Out:
#                                                  img  \
# 8486                      /games/boxart/21030ccc.jpg
# 10832                   /games/boxart/2426879ccc.jpg
# 18185                   /games/boxart/8436780ccc.jpg
# 18455                      /games/boxart/default.jpg
# 19925                      /games/boxart/default.jpg
# 25045                      /games/boxart/default.jpg
# 27407  /games/boxart/full_7747476AmericaFrontccc.jpg
# 31230      /games/boxart/full_8222233PALFrontccc.png
# 37057                   /games/boxart/1105699ccc.jpg
# 40753                      /games/boxart/default.jpg
# 43679                      /games/boxart/default.jpg
# 43831  /games/boxart/full_6465496AmericaFrontccc.jpg
# 50450                    /games/boxart/101505ccc.jpg
# 50592                      /games/boxart/default.jpg
# 55431  /games/boxart/full_6511154AmericaFrontccc.png
# 55432  /games/boxart/full_6946845AmericaFrontccc.jpg
# 62494                      /games/boxart/default.jpg
#
# ...

# %%
b = file.isnull().sum()
print(b)
# Out:
# img                 0
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
missing_developers = file[file['developer'].isnull()]
missing_developers
# Out:
#                                                  img  \
# 8486                      /games/boxart/21030ccc.jpg
# 10832                   /games/boxart/2426879ccc.jpg
# 18185                   /games/boxart/8436780ccc.jpg
# 18455                      /games/boxart/default.jpg
# 19925                      /games/boxart/default.jpg
# 25045                      /games/boxart/default.jpg
# 27407  /games/boxart/full_7747476AmericaFrontccc.jpg
# 31230      /games/boxart/full_8222233PALFrontccc.png
# 37057                   /games/boxart/1105699ccc.jpg
# 40753                      /games/boxart/default.jpg
# 43679                      /games/boxart/default.jpg
# 43831  /games/boxart/full_6465496AmericaFrontccc.jpg
# 50450                    /games/boxart/101505ccc.jpg
# 50592                      /games/boxart/default.jpg
# 55431  /games/boxart/full_6511154AmericaFrontccc.png
# 55432  /games/boxart/full_6946845AmericaFrontccc.jpg
# 62494                      /games/boxart/default.jpg
#
# ...

# %%
file.tail()
# Out:
#                                                  img  \
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  na_sales  \
# 64011           Aksys Games      Arc System Works           NaN       NaN
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN       NaN
# ...

# %%
#From this we get to know there are 64015 games in this data set

# %%
a = file.shape[0]
# Out:
# 64016

# %%
ratio = b/64016
print(ratio)
# Out:
# img             0.000000
# title           0.000000
# console         0.000000
# genre           0.000000
# publisher       0.000000
# developer       0.000266
# critic_score    0.895682
# na_sales        0.802596
# jp_sales        0.894933
# pal_sales       0.799675
# other_sales     0.763684
# release_date    0.110144
# last_update     0.720710
# dtype: float64

# %%
Percentage = ratio*100

# %%
print(Percentage)
# Out:
# img              0.000000
# title            0.000000
# console          0.000000
# genre            0.000000
# publisher        0.000000
# developer        0.026556
# critic_score    89.568233
# na_sales        80.259623
# jp_sales        89.493252
# pal_sales       79.967508
# other_sales     76.368408
# release_date    11.014434
# last_update     72.071045
# dtype: float64

# %%
threshold = 50 # Just to make sure we remove those columns with high percentage of missing data

# %%
cols_to_be_dropped = Percentage[Percentage > threshold].index

# %%
file = file.drop(columns = cols_to_be_dropped)

# %%
print(cols_to_be_dropped)
# Out:
# Index(['critic_score', 'na_sales', 'jp_sales', 'pal_sales', 'other_sales',
#        'last_update'],
#       dtype='object')

# %%
file.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer release_date
# 0     PS3   Action  Rockstar Games  Rockstar North   2013-09-17
# 1     PS4   Action  Rockstar Games  Rockstar North   2014-11-18
# 2     PS2   Action  Rockstar Games  Rockstar North   2002-10-28
# 3    X360   Action  Rockstar Games  Rockstar North   2013-09-17
# 4     PS4  Shooter      Activision        Treyarch   2015-11-06

# %%
file.isnull().sum()
# Out:
# img                0
# title              0
# console            0
# genre              0
# publisher          0
# developer         17
# release_date    7051
# dtype: int64

# %%
mode_release_date = file['release_date'].mode()[0]  # Get the most frequent value
print(mode_release_date)
# Out:
# 1994-01-01

# %%
file['release_date'] = file['release_date'].fillna(mode_release_date)

# %%
file.isnull().sum()
# Out:
# img              0
# title            0
# console          0
# genre            0
# publisher        0
# developer       17
# release_date     0
# dtype: int64

# %%
file['Developer Missing'] = file['developer'].isnull().astype(int)

# %%
file.describe()
# Out:
#        Developer Missing
# count       64016.000000
# mean            0.000266
# std             0.016294
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000

# %%
file.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer release_date  \
# 0     PS3   Action  Rockstar Games  Rockstar North   2013-09-17
# 1     PS4   Action  Rockstar Games  Rockstar North   2014-11-18
# 2     PS2   Action  Rockstar Games  Rockstar North   2002-10-28
# 3    X360   Action  Rockstar Games  Rockstar North   2013-09-17
# 4     PS4  Shooter      Activision        Treyarch   2015-11-06
#
#    Developer Missing
# 0                  0
# 1                  0
# 2                  0
# ...

# %%
file = pd.read_csv("vgchartz-2024.csv")

# %%
file['Total Sales'] = file[['na_sales', 'jp_sales', 'pal_sales', 'other_sales']].sum(axis=1)

# %%
file.describe()
# Out:
#        critic_score      na_sales     jp_sales     pal_sales   other_sales  \
# count   6678.000000  12637.000000  6726.000000  12824.000000  15128.000000
# mean       7.220440      0.264740     0.102281      0.149472      0.043041
# std        1.457066      0.494787     0.168811      0.392653      0.126643
# min        1.000000      0.000000     0.000000      0.000000      0.000000
# 25%        6.400000      0.050000     0.020000      0.010000      0.000000
# 50%        7.500000      0.120000     0.040000      0.040000      0.010000
# 75%        8.300000      0.280000     0.120000      0.140000      0.030000
# max       10.000000      9.760000     2.130000      9.850000      3.120000
#
#         total_sales   Total Sales
# count  64016.000000  64016.000000
# mean       0.103121      0.103121
# std        0.467071      0.467071
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.020000      0.020000
# ...

# %%
mean_val = np.mean(file['Total Sales'])
median_val = np.median(file['Total Sales'])
std_val = np.std(file['Total Sales'])

# %%
print(f"Mean: {mean_val}, Median: {median_val}, Standard Deviation: {std_val}")
# Out:
# Mean: 0.1031212509372657, Median: 0.0, Standard Deviation: 0.4670673936189395

# %%
filtered_data = filtered_data = file[file['Total Sales'] > 13]

# %%
filtered_data.head(14)
# Out:
#                                                   img  \
# 0       /games/boxart/full_6510540AmericaFrontccc.jpg
# 1       /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                         /games/boxart/827563ccc.jpg
# 3       /games/boxart/full_9218923AmericaFrontccc.jpg
# 4       /games/boxart/full_4990510AmericaFrontccc.jpg
# 5   /games/boxart/full_call-of-duty-modern-warfare...
# 6   /games/boxart/full_call-of-duty-black-ops_5Ame...
# 7       /games/boxart/full_4653215AmericaFrontccc.jpg
# 8       /games/boxart/full_1977964AmericaFrontccc.jpg
# 9       /games/boxart/full_4649679AmericaFrontccc.png
# 10       /games/boxart/full_809251AmericaFrontccc.jpg
# 11      /games/boxart/full_4380292AmericaFrontccc.jpg
# 12  /games/boxart/full_call-of-duty-modern-warfare...
# 13                       /games/boxart/3570928ccc.jpg
#
#                              title console             genre       publisher  \
# ...

# %%
import pandas as pd
file = pd.read_csv("vgchartz-2024.csv")
import numpy as np
file['total_sales'] = np.sum(file[['na_sales', 'jp_sales', 'pal_sales', 'other_sales']], axis=1)

# %%
file.describe()
# Out:
#        critic_score      na_sales     jp_sales     pal_sales   other_sales  \
# count   6678.000000  12637.000000  6726.000000  12824.000000  15128.000000
# mean       7.220440      0.264740     0.102281      0.149472      0.043041
# std        1.457066      0.494787     0.168811      0.392653      0.126643
# min        1.000000      0.000000     0.000000      0.000000      0.000000
# 25%        6.400000      0.050000     0.020000      0.010000      0.000000
# 50%        7.500000      0.120000     0.040000      0.040000      0.010000
# 75%        8.300000      0.280000     0.120000      0.140000      0.030000
# max       10.000000      9.760000     2.130000      9.850000      3.120000
#
#         total_sales
# count  64016.000000
# mean       0.103121
# std        0.467071
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.020000
# max       20.330000

# %%
file.to_csv("output.csv", index=False)

# %%
from IPython.display import FileLink
FileLink("output.csv")
# Out:
# D:\Envision Project\output.csv

# %%
import os
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor, AutoConfig
from torch.optim import AdamW
from tqdm.auto import tqdm
import numpy as np

# --- Configuration ---
MODEL_NAME = "facebook/wav2vec2-base-960h"
DATA_ROOT = "./data_librispeech_asr"
OUTPUT_DIR = "./wav2vec2_librispeech_finetuned"
NUM_EPOCHS = 5
BATCH_SIZE = 2
LEARNING_RATE = 3e-5
GRAD_CLIP_NORM = 1.0
MAX_SAMPLES = 300
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Using device: {DEVICE}")
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

# --- 1. Load Pre-trained Model, Processor and Config ---
print(f"Loading model, processor, and config for: {MODEL_NAME}...")
processor = Wav2Vec2Processor.from_pretrained(MODEL_NAME)
model_config = AutoConfig.from_pretrained(MODEL_NAME)
model = Wav2Vec2ForCTC.from_pretrained(MODEL_NAME)
model.to(DEVICE)
model.freeze_feature_encoder()

# --- 1.5 Verify Critical Tokenizer and Model Config ---
print("\n--- Verifying Tokenizer and Model Config ---")
if model.config.pad_token_id != processor.tokenizer.pad_token_id:
    print(f"CRITICAL WARNING: Model's pad_token_id ({model.config.pad_token_id}) and "
          f"Processor's pad_token_id ({processor.tokenizer.pad_token_id}) DO NOT MATCH!")
    print("This will likely lead to incorrect CTC behavior. Ensure they are aligned.")
else:
    print(f"Model CTC Blank ID (model.config.pad_token_id): {model.config.pad_token_id}")
    print(f"Processor Padding ID (processor.tokenizer.pad_token_id): {processor.tokenizer.pad_token_id}")
    print("Pad token IDs match. OK.")
print(f"Model inputs_to_logits_ratio: {model_config.inputs_to_logits_ratio}")
print("--- End Verification ---\n")

# --- 2. Load Dataset ---
print("Loading LibriSpeech dataset...")
try:
    librispeech_dataset_full = torchaudio.datasets.LIBRISPEECH(
        root=DATA_ROOT,
        url="train-clean-100",
        download=True
    )
except Exception as e:
    print(f"Error downloading/loading LibriSpeech. If it's a checksum error, try deleting the downloaded archive in {DATA_ROOT}/LibriSpeech and re-running.")
    print(f"Details: {e}")
    exit()

class SubsetDataset(Dataset):
    def __init__(self, full_dataset, num_samples):
        self.full_dataset = full_dataset
        self.indices = list(range(min(num_samples, len(full_dataset))))

    def __getitem__(self, idx):
        return self.full_dataset[self.indices[idx]]

    def __len__(self):
        return len(self.indices)

dataset = SubsetDataset(librispeech_dataset_full, MAX_SAMPLES)
print(f"Using {len(dataset)} samples for training.")

# --- 3. Custom PyTorch Dataset for Preprocessing ---
class AudioDataset(Dataset):
    def __init__(self, torchaudio_dataset, processor, target_sample_rate=16000):
        self.torchaudio_dataset = torchaudio_dataset
        self.processor = processor
        self.target_sample_rate = target_sample_rate
        self.inputs_to_logits_ratio = model_config.inputs_to_logits_ratio

    def __len__(self):
        return len(self.torchaudio_dataset)

    def __getitem__(self, idx):
        try:
            waveform, sample_rate, utterance, speaker_id, chapter_id, utterance_id = self.torchaudio_dataset[idx]
        except Exception:
            return None

        if not utterance.strip():
            return None

        if sample_rate != self.target_sample_rate:
            resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=self.target_sample_rate)
            waveform = resampler(waveform)

        waveform_squeezed = waveform.squeeze(0)
        if waveform_squeezed.ndim == 0:
            return None

        if waveform_squeezed.shape[0] < self.inputs_to_logits_ratio:
            return None

        input_values = self.processor(
            waveform_squeezed,
            sampling_rate=self.target_sample_rate,
            return_tensors="pt"
        ).input_values.squeeze(0)

        # Process transcript for labels (removed `as_target_processor` context)
        labels_dict = self.processor.tokenizer(
            utterance.upper(),
            return_tensors="pt",
            padding=False,
            truncation=False,
            add_special_tokens=False
        )
        labels = labels_dict.input_ids.squeeze(0)

        if labels.nelement() == 0:
            return None

        expected_logits_len = waveform_squeezed.shape[0] // self.inputs_to_logits_ratio
        if expected_logits_len < labels.shape[0]:
            return None

        return {
            "input_values": input_values,
            "labels": labels,
            "id": f"{speaker_id}-{chapter_id}-{utterance_id}",
            "waveform_len_debug": waveform_squeezed.shape[0],
            "label_len_debug": labels.shape[0]
        }

processed_dataset = AudioDataset(dataset, processor)
test_dataset = AudioDataset(librispeech_dataset_full, processor)

# --- 4. Custom Data Collator ---
class CustomDataCollatorCTCWithPadding:
    def __init__(self, processor):
        self.processor = processor
        self.audio_padding_value = 0.0
        self.label_padding_token_id = self.processor.tokenizer.pad_token_id
        if self.label_padding_token_id is None:
            print("Warning: processor.tokenizer.pad_token_id is None. Defaulting label padding to 0.")
            self.label_padding_token_id = 0

    def __call__(self, features):
        valid_features = [f for f in features if f is not None]
        if not valid_features:
            return {}

        input_values_list = [feature["input_values"] for feature in valid_features]
        labels_list = [feature["labels"] for feature in valid_features]

        # Pad audio by passing a dictionary to feature_extractor.pad
        audio_to_pad = {"input_values": input_values_list}
        batch_padded_audio = self.processor.feature_extractor.pad(
            audio_to_pad, # Pass the dictionary
            padding=True,
            return_tensors="pt",
            pad_to_multiple_of=None,
            return_attention_mask=True  # Ensure mask is returned
        )

        # Pad labels
        max_label_len = max(len(lab) for lab in labels_list)
        padded_labels_list = []
        for lab in labels_list:
            padding_needed = max_label_len - len(lab)
            padded_lab = torch.cat([lab, torch.full((padding_needed,), self.label_padding_token_id, dtype=lab.dtype)], dim=0)
            padded_labels_list.append(padded_lab)
        batch_labels = torch.stack(padded_labels_list)

        batch_ids = [f.get("id", "unknown") for f in valid_features]
        waveform_lengths = [f.get("waveform_len_debug", 0) for f in valid_features]
        label_lengths = [f.get("label_len_debug", 0) for f in valid_features]

        return {
            "input_values": batch_padded_audio.input_values,
            "attention_mask": batch_padded_audio.attention_mask,
            "labels": batch_labels,
            "ids_debug": batch_ids,
            "waveform_lengths_debug": waveform_lengths,
            "label_lengths_debug": label_lengths
        }

data_collator = CustomDataCollatorCTCWithPadding(processor=processor)

train_dataloader = DataLoader(
    processed_dataset,
    batch_size=BATCH_SIZE,
    collate_fn=data_collator,
    shuffle=True,
    num_workers=2 # Set to 0 if you still face issues, to debug in main thread
)

# --- 5. Sanity Check Dataloader Output ---
print("\n--- Sanity Checking Dataloader Output ---")
num_valid_samples_in_processed_dataset = 0
for i in range(len(processed_dataset)):
    if processed_dataset[i] is not None:
        num_valid_samples_in_processed_dataset +=1
print(f"Total samples in original subset: {len(dataset)}")
print(f"Effective samples after AudioDataset filtering: {num_valid_samples_in_processed_dataset}")

if num_valid_samples_in_processed_dataset > 0:
    try:
        for i, batch_sanity in enumerate(train_dataloader):
            if i >= 1: break
            if not batch_sanity: print(f"Sanity check: Batch {i} is empty."); continue

            print(f"\nSanity Check Batch {i}:")
            print(f"  Input values shape: {batch_sanity['input_values'].shape}")
            print(f"  Attention mask shape: {batch_sanity['attention_mask'].shape}")
            print(f"  Labels shape: {batch_sanity['labels'].shape}")
            # Ensure labels tensor is not empty before decoding and accessing index 0
            if batch_sanity['labels'].numel() > 0 and len(batch_sanity['labels']) > 0:
                 print(f"  Sample 0 Decoded Labels (first 50 chars): '{processor.decode(batch_sanity['labels'][0].tolist())[:50]}'")
            else:
                print("  Sample 0 Labels are empty or not present for decoding.")

            if batch_sanity.get('waveform_lengths_debug') and len(batch_sanity['waveform_lengths_debug']) > 0:
                wf_len_s0 = batch_sanity['waveform_lengths_debug'][0]
                lbl_len_s0 = batch_sanity['label_lengths_debug'][0]
                exp_logits_s0 = wf_len_s0 // model_config.inputs_to_logits_ratio
                print(f"  Sample 0 CTC check: WF_len={wf_len_s0}, ExpLogits={exp_logits_s0}, Lbl_len={lbl_len_s0}. Valid: {exp_logits_s0 >= lbl_len_s0}")
                if not (exp_logits_s0 >= lbl_len_s0):
                    print(f"    WARNING: Sample 0 may fail CTC length constraint in model!")
            else:
                print("  Debug lengths not available for Sample 0.")
    except Exception as e:
        print(f"Error during dataloader sanity check: {e}")
        import traceback
        traceback.print_exc() # Print full traceback for dataloader errors
        print("This might indicate an issue with data processing or collation.")
else:
    print("Effective dataset size is 0. Cannot perform dataloader sanity check. Check filtering in AudioDataset.")
print("--- End Sanity Checking ---\n")

# --- 6. Optimizer ---
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)

# --- 7. Training Loop ---
print("Starting training...")
model.train()
avg_epoch_loss = float('nan') # Initialize in case no valid batches
num_valid_batches_epoch = 0   # Initialize

for epoch in range(NUM_EPOCHS):
    epoch_loss, num_valid_batches_epoch, num_nan_batches_epoch = 0, 0, 0
    progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for batch_idx, batch in enumerate(progress_bar):
        if not batch or "input_values" not in batch or batch["input_values"] is None:
            print(f"Skipping empty or invalid batch at epoch {epoch+1}, index {batch_idx}")
            continue

        optimizer.zero_grad()

        input_values = batch["input_values"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)

        try:
            outputs = model(input_values, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss

            if torch.isnan(loss) or torch.isinf(loss):
                num_nan_batches_epoch += 1
                print(f"\nNaN/Inf loss detected! Epoch {epoch+1}, Batch {batch_idx}. IDs: {batch.get('ids_debug', 'N/A')}")
                print(f"  Input values: min={input_values.min():.2e}, max={input_values.max():.2e}, mean={input_values.mean():.2e}")
                if hasattr(outputs, 'logits') and outputs.logits is not None:
                    print(f"  Logits: min={outputs.logits.min():.2e}, max={outputs.logits.max():.2e}, mean={outputs.logits.mean():.2e}, has_nan={torch.isnan(outputs.logits).any()}")
                for i in range(labels.size(0)):
                    current_labels = labels[i]
                    effective_label_length = (current_labels != processor.tokenizer.pad_token_id).sum().item()
                    if effective_label_length == 0 and model.config.ctc_zero_infinity is False:
                        print(f"  Sample {i} (ID: {batch.get('ids_debug', ['N/A']*labels.size(0))[i]}) has effective zero-length label. This can cause inf loss if ctc_zero_infinity=False.")
                optimizer.zero_grad(set_to_none=True)
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP_NORM)
            optimizer.step()

            epoch_loss += loss.item()
            num_valid_batches_epoch += 1
            progress_bar.set_postfix({"loss": loss.item(), "lr": optimizer.param_groups[0]['lr'], "nans": num_nan_batches_epoch})

        except Exception as e:
            print(f"\nError during model forward/backward pass at Epoch {epoch+1}, Batch {batch_idx}: {e}")
            print(f"  Input values shape: {input_values.shape}, attention_mask shape: {attention_mask.shape if attention_mask is not None else 'None'}, labels shape: {labels.shape}")
            print(f"  Batch IDs: {batch.get('ids_debug', 'N/A')}")
            import traceback
            traceback.print_exc()
            optimizer.zero_grad(set_to_none=True) # Ensure grads are cleared
            num_nan_batches_epoch +=1 # Count as a problematic batch
            continue


    avg_epoch_loss = epoch_loss / num_valid_batches_epoch if num_valid_batches_epoch > 0 else float('nan')
    print(f"Epoch {epoch+1}/{NUM_EPOCHS} - Avg Loss: {avg_epoch_loss:.4f}, Valid Batches: {num_valid_batches_epoch}, NaN Batches: {num_nan_batches_epoch}")

# --- 8. Saving the Model and Processor ---
if num_valid_batches_epoch > 0 and not np.isnan(avg_epoch_loss):
    print(f"\nSaving fine-tuned model and processor to {OUTPUT_DIR}...")
    model.save_pretrained(OUTPUT_DIR)
    processor.save_pretrained(OUTPUT_DIR)
    print("Training complete and model saved.")
else:
    print("\nSkipping model saving due to NaN losses or no valid batches during training.")
# Out:
# Using device: cuda
# Loading model, processor, and config for: facebook/wav2vec2-base-960h...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# --- Verifying Tokenizer and Model Config ---
# Model CTC Blank ID (model.config.pad_token_id): 0
# Processor Padding ID (processor.tokenizer.pad_token_id): 0
# Pad token IDs match. OK.
# Model inputs_to_logits_ratio: 320
# --- End Verification ---
#
# Loading LibriSpeech dataset...
# 100%|██████████| 5.95G/5.95G [02:51<00:00, 37.2MB/s]
# Using 300 samples for training.
#
# --- Sanity Checking Dataloader Output ---
# Total samples in original subset: 300
# Effective samples after AudioDataset filtering: 300
#
# Sanity Check Batch 0:
#   Input values shape: torch.Size([2, 249040])
#   Attention mask shape: torch.Size([2, 249040])
#   Labels shape: torch.Size([2, 338])
#   Sample 0 Decoded Labels (first 50 chars): 'PALE AND COLD ADIEU SIR SHE SAID ADIEU MADAME REPL'
#   Sample 0 CTC check: WF_len=166400, ExpLogits=520, Lbl_len=132. Valid: True
# --- End Sanity Checking ---
#
# Starting training...
# Epoch 1/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 1, Batch 1. IDs: ['103-1240-40', '103-1241-43']
#   Input values: min=-1.45e+01, max=1.09e+01, mean=-6.70e-10
#   Logits: min=-3.43e+01, max=1.46e+01, mean=-3.85e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 8. IDs: ['1034-121119-78', '1034-121119-80']
#   Input values: min=-9.56e+00, max=8.91e+00, mean=1.01e-09
#   Logits: min=-3.15e+01, max=1.71e+01, mean=-3.99e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 11. IDs: ['1034-121119-17', '1034-121119-45']
#   Input values: min=-1.09e+01, max=1.18e+01, mean=-1.65e-09
#   Logits: min=-3.69e+01, max=1.52e+01, mean=-4.13e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 13. IDs: ['103-1240-7', '1034-121119-9']
#   Input values: min=-1.57e+01, max=1.11e+01, mean=0.00e+00
#   Logits: min=-5.72e+01, max=1.66e+01, mean=-3.35e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 18. IDs: ['103-1241-23', '1034-121119-12']
#   Input values: min=-3.26e+01, max=1.92e+01, mean=3.79e-09
#   Logits: min=-2.90e+01, max=9.61e+00, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 19. IDs: ['1034-121119-24', '103-1241-5']
#   Input values: min=-1.39e+01, max=1.14e+01, mean=-1.94e-09
#   Logits: min=-3.80e+01, max=1.59e+01, mean=-3.81e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 21. IDs: ['1040-133433-7', '1040-133433-38']
#   Input values: min=-8.41e+00, max=1.13e+01, mean=-7.90e-11
#   Logits: min=-3.07e+01, max=1.34e+01, mean=-3.29e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 22. IDs: ['1034-121119-67', '103-1240-24']
#   Input values: min=-1.20e+01, max=9.91e+00, mean=2.06e-09
#   Logits: min=-2.88e+01, max=1.27e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 28. IDs: ['1034-121119-48', '1034-121119-26']
#   Input values: min=-1.13e+01, max=1.11e+01, mean=1.82e-09
#   Logits: min=-3.12e+01, max=1.33e+01, mean=-3.44e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 34. IDs: ['1034-121119-21', '1040-133433-17']
#   Input values: min=-1.10e+01, max=1.14e+01, mean=3.99e-10
#   Logits: min=-3.10e+01, max=1.03e+01, mean=-3.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 35. IDs: ['1040-133433-64', '103-1241-4']
#   Input values: min=-2.09e+01, max=1.18e+01, mean=1.17e-09
#   Logits: min=-2.93e+01, max=1.17e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 43. IDs: ['103-1240-52', '1034-121119-93']
#   Input values: min=-1.85e+01, max=1.13e+01, mean=-1.29e-10
#   Logits: min=-2.90e+01, max=1.06e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 44. IDs: ['103-1240-15', '103-1240-11']
#   Input values: min=-1.56e+01, max=9.86e+00, mean=2.49e-09
#   Logits: min=-2.86e+01, max=1.26e+01, mean=-3.24e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 46. IDs: ['103-1241-20', '1034-121119-92']
#   Input values: min=-1.77e+01, max=1.29e+01, mean=-3.90e-09
#   Logits: min=-5.14e+01, max=1.41e+01, mean=-3.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 53. IDs: ['1040-133433-61', '1034-121119-88']
#   Input values: min=-1.52e+01, max=1.90e+01, mean=-1.81e-09
#   Logits: min=-2.80e+01, max=1.17e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 63. IDs: ['1040-133433-60', '1034-121119-15']
#   Input values: min=-1.22e+01, max=2.08e+01, mean=-3.86e-09
#   Logits: min=-2.86e+01, max=9.51e+00, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 64. IDs: ['1034-121119-68', '103-1240-51']
#   Input values: min=-1.90e+01, max=1.53e+01, mean=2.79e-09
#   Logits: min=-2.89e+01, max=1.23e+01, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 66. IDs: ['1034-121119-32', '1034-121119-46']
#   Input values: min=-1.05e+01, max=8.97e+00, mean=3.13e-09
#   Logits: min=-4.68e+01, max=1.43e+01, mean=-3.33e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 68. IDs: ['1040-133433-63', '1040-133433-24']
#   Input values: min=-1.60e+01, max=1.46e+01, mean=1.74e-10
#   Logits: min=-2.54e+01, max=8.90e+00, mean=-2.98e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 69. IDs: ['103-1241-9', '1069-133699-9']
#   Input values: min=-2.64e+01, max=2.29e+01, mean=3.26e-10
#   Logits: min=-3.29e+01, max=1.10e+01, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 70. IDs: ['1040-133433-54', '1040-133433-33']
#   Input values: min=-9.70e+00, max=1.36e+01, mean=1.41e-09
#   Logits: min=-3.78e+01, max=1.67e+01, mean=-3.39e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 72. IDs: ['1034-121119-35', '103-1241-10']
#   Input values: min=-1.17e+01, max=8.24e+00, mean=1.68e-09
#   Logits: min=-3.24e+01, max=1.53e+01, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 75. IDs: ['103-1241-13', '1034-121119-76']
#   Input values: min=-1.65e+01, max=9.30e+00, mean=1.55e-09
#   Logits: min=-5.06e+01, max=1.73e+01, mean=-3.77e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 89. IDs: ['103-1241-2', '1034-121119-18']
#   Input values: min=-1.33e+01, max=8.61e+00, mean=7.66e-10
#   Logits: min=-3.20e+01, max=1.22e+01, mean=-3.12e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 94. IDs: ['1034-121119-54', '103-1241-34']
#   Input values: min=-1.44e+01, max=1.09e+01, mean=-1.38e-09
#   Logits: min=-3.01e+01, max=1.14e+01, mean=-3.04e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 96. IDs: ['1040-133433-78', '1034-121119-49']
#   Input values: min=-1.61e+01, max=1.30e+01, mean=5.80e-09
#   Logits: min=-2.94e+01, max=1.06e+01, mean=-2.87e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 107. IDs: ['1034-121119-77', '103-1240-53']
#   Input values: min=-1.64e+01, max=9.70e+00, mean=2.03e-09
#   Logits: min=-5.71e+01, max=1.82e+01, mean=-3.74e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 114. IDs: ['1040-133433-46', '1040-133433-70']
#   Input values: min=-1.07e+01, max=1.27e+01, mean=-3.38e-09
#   Logits: min=-3.11e+01, max=1.01e+01, mean=-3.38e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 117. IDs: ['1034-121119-90', '1040-133433-26']
#   Input values: min=-1.33e+01, max=1.47e+01, mean=-2.63e-09
#   Logits: min=-3.14e+01, max=1.24e+01, mean=-3.31e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 120. IDs: ['1034-121119-10', '1069-133699-6']
#   Input values: min=-8.71e+00, max=8.08e+00, mean=-2.74e-09
#   Logits: min=-3.18e+01, max=1.22e+01, mean=-3.41e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 128. IDs: ['1040-133433-36', '103-1241-19']
#   Input values: min=-1.45e+01, max=1.23e+01, mean=2.65e-09
#   Logits: min=-2.91e+01, max=1.09e+01, mean=-3.13e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 134. IDs: ['1040-133433-10', '1034-121119-29']
#   Input values: min=-1.05e+01, max=1.27e+01, mean=-2.03e-09
#   Logits: min=-2.92e+01, max=1.03e+01, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 145. IDs: ['103-1240-26', '103-1241-36']
#   Input values: min=-2.02e+01, max=1.57e+01, mean=8.96e-10
#   Logits: min=-2.66e+01, max=1.04e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 149. IDs: ['1034-121119-22', '103-1240-29']
#   Input values: min=-1.39e+01, max=8.67e+00, mean=-1.81e-09
#   Logits: min=-3.05e+01, max=1.12e+01, mean=-2.97e+00, has_nan=False
# Epoch 1/5 - Avg Loss: 463.2210, Valid Batches: 116, NaN Batches: 34
# Epoch 2/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 2, Batch 4. IDs: ['103-1240-46', '1034-121119-65']
#   Input values: min=-1.51e+01, max=9.70e+00, mean=3.60e-09
#   Logits: min=-4.39e+01, max=1.51e+01, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 8. IDs: ['103-1241-25', '103-1240-25']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=6.78e-10
#   Logits: min=-3.15e+01, max=1.19e+01, mean=-3.08e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 14. IDs: ['1069-133699-18', '1034-121119-54']
#   Input values: min=-1.06e+01, max=1.06e+01, mean=6.84e-10
#   Logits: min=-2.63e+01, max=8.57e+00, mean=-2.85e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 24. IDs: ['1040-133433-32', '1034-121119-38']
#   Input values: min=-9.59e+00, max=1.81e+01, mean=3.22e-09
#   Logits: min=-2.84e+01, max=1.12e+01, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 31. IDs: ['1034-121119-22', '103-1240-27']
#   Input values: min=-1.44e+01, max=9.08e+00, mean=2.77e-09
#   Logits: min=-3.33e+01, max=1.26e+01, mean=-3.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 35. IDs: ['1040-133433-8', '1034-121119-76']
#   Input values: min=-1.22e+01, max=1.24e+01, mean=-1.59e-09
#   Logits: min=-2.84e+01, max=9.72e+00, mean=-3.00e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 39. IDs: ['1069-133699-9', '103-1241-28']
#   Input values: min=-1.47e+01, max=1.08e+01, mean=-8.55e-10
#   Logits: min=-3.00e+01, max=1.06e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 40. IDs: ['1069-133699-14', '1040-133433-78']
#   Input values: min=-8.96e+00, max=1.14e+01, mean=-1.37e-09
#   Logits: min=-3.00e+01, max=1.06e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 44. IDs: ['1069-133699-19', '1034-121119-21']
#   Input values: min=-1.08e+01, max=8.90e+00, mean=2.04e-09
#   Logits: min=-2.53e+01, max=8.72e+00, mean=-2.87e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 45. IDs: ['103-1240-54', '1034-121119-92']
#   Input values: min=-1.48e+01, max=9.88e+00, mean=-1.94e-09
#   Logits: min=-5.87e+01, max=1.84e+01, mean=-3.27e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 49. IDs: ['103-1240-15', '103-1241-33']
#   Input values: min=-1.65e+01, max=8.39e+00, mean=-1.33e-09
#   Logits: min=-3.22e+01, max=1.27e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 51. IDs: ['1034-121119-77', '1040-133433-66']
#   Input values: min=-7.87e+00, max=8.74e+00, mean=-1.76e-09
#   Logits: min=-2.54e+01, max=8.35e+00, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 56. IDs: ['1034-121119-52', '1040-133433-48']
#   Input values: min=-1.17e+01, max=1.68e+01, mean=2.39e-09
#   Logits: min=-2.74e+01, max=1.17e+01, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 59. IDs: ['1040-133433-79', '1040-133433-70']
#   Input values: min=-1.17e+01, max=1.27e+01, mean=-1.84e-09
#   Logits: min=-3.16e+01, max=1.16e+01, mean=-3.27e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 61. IDs: ['1040-133433-52', '1034-121119-46']
#   Input values: min=-9.93e+00, max=1.25e+01, mean=-1.25e-09
#   Logits: min=-2.63e+01, max=9.74e+00, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 65. IDs: ['1034-121119-86', '1040-133433-38']
#   Input values: min=-9.43e+00, max=1.13e+01, mean=-1.32e-09
#   Logits: min=-2.87e+01, max=9.40e+00, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 66. IDs: ['1034-121119-59', '1034-121119-7']
#   Input values: min=-8.29e+00, max=9.59e+00, mean=3.59e-09
#   Logits: min=-3.67e+01, max=1.55e+01, mean=-3.54e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 68. IDs: ['1034-121119-5', '1034-121119-24']
#   Input values: min=-8.91e+00, max=9.00e+00, mean=2.04e-09
#   Logits: min=-3.32e+01, max=1.16e+01, mean=-3.34e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 70. IDs: ['1034-121119-9', '1034-121119-71']
#   Input values: min=-1.61e+01, max=1.83e+01, mean=5.46e-09
#   Logits: min=-2.40e+01, max=7.01e+00, mean=-2.70e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 72. IDs: ['103-1240-56', '1034-121119-93']
#   Input values: min=-1.08e+01, max=9.18e+00, mean=7.79e-10
#   Logits: min=-3.56e+01, max=1.38e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 86. IDs: ['103-1241-19', '1034-121119-57']
#   Input values: min=-1.45e+01, max=1.16e+01, mean=6.66e-09
#   Logits: min=-3.12e+01, max=1.23e+01, mean=-3.27e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 96. IDs: ['103-1240-57', '1034-121119-6']
#   Input values: min=-1.04e+01, max=8.50e+00, mean=-4.50e-09
#   Logits: min=-4.95e+01, max=1.90e+01, mean=-3.67e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 98. IDs: ['103-1241-38', '1034-121119-26']
#   Input values: min=-1.80e+01, max=1.21e+01, mean=-5.36e-09
#   Logits: min=-3.37e+01, max=1.29e+01, mean=-3.31e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 99. IDs: ['1034-121119-35', '1069-133699-6']
#   Input values: min=-8.12e+00, max=8.08e+00, mean=-3.18e-09
#   Logits: min=-3.03e+01, max=1.24e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 104. IDs: ['1040-133433-17', '1034-121119-67']
#   Input values: min=-1.10e+01, max=1.14e+01, mean=1.33e-10
#   Logits: min=-3.15e+01, max=1.21e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 105. IDs: ['1034-121119-17', '1034-121119-1']
#   Input values: min=-1.21e+01, max=1.10e+01, mean=2.93e-10
#   Logits: min=-3.29e+01, max=1.23e+01, mean=-3.42e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 106. IDs: ['1040-133433-64', '1034-121119-60']
#   Input values: min=-1.61e+01, max=1.18e+01, mean=-6.40e-09
#   Logits: min=-3.09e+01, max=1.14e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 107. IDs: ['1034-121119-75', '103-1240-51']
#   Input values: min=-1.90e+01, max=1.21e+01, mean=-4.08e-09
#   Logits: min=-5.03e+01, max=1.87e+01, mean=-3.62e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 109. IDs: ['103-1241-35', '1034-121119-80']
#   Input values: min=-1.73e+01, max=9.94e+00, mean=-2.54e-09
#   Logits: min=-3.27e+01, max=1.31e+01, mean=-3.27e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 110. IDs: ['1034-121119-36', '103-1240-34']
#   Input values: min=-1.67e+01, max=1.52e+01, mean=1.24e-09
#   Logits: min=-3.31e+01, max=1.37e+01, mean=-3.29e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 112. IDs: ['1034-121119-42', '1034-121119-31']
#   Input values: min=-8.95e+00, max=1.01e+01, mean=-5.21e-09
#   Logits: min=-3.20e+01, max=1.06e+01, mean=-3.24e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 117. IDs: ['103-1241-18', '1034-121119-10']
#   Input values: min=-2.08e+01, max=1.57e+01, mean=2.11e-09
#   Logits: min=-3.16e+01, max=1.12e+01, mean=-3.33e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 119. IDs: ['103-1241-36', '1034-121119-61']
#   Input values: min=-1.26e+01, max=1.31e+01, mean=2.11e-09
#   Logits: min=-3.32e+01, max=1.30e+01, mean=-3.35e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 123. IDs: ['1034-121119-41', '1034-121119-51']
#   Input values: min=-1.09e+01, max=1.03e+01, mean=-8.66e-09
#   Logits: min=-2.73e+01, max=9.94e+00, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 127. IDs: ['103-1241-31', '1034-121119-12']
#   Input values: min=-2.39e+01, max=1.85e+01, mean=5.88e-09
#   Logits: min=-3.17e+01, max=1.24e+01, mean=-3.12e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 128. IDs: ['1034-121119-89', '1034-121119-11']
#   Input values: min=-1.05e+01, max=1.24e+01, mean=6.07e-09
#   Logits: min=-3.15e+01, max=1.31e+01, mean=-3.25e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 129. IDs: ['1040-133433-21', '1040-133433-74']
#   Input values: min=-1.44e+01, max=1.93e+01, mean=7.24e-10
#   Logits: min=-3.22e+01, max=1.17e+01, mean=-3.20e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 132. IDs: ['1034-121119-88', '1034-121119-19']
#   Input values: min=-9.63e+00, max=8.74e+00, mean=7.93e-09
#   Logits: min=-3.09e+01, max=1.14e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 133. IDs: ['1034-121119-84', '1069-133699-1']
#   Input values: min=-1.04e+01, max=1.04e+01, mean=-1.02e-09
#   Logits: min=-3.27e+01, max=1.17e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 137. IDs: ['103-1241-43', '1040-133433-2']
#   Input values: min=-1.32e+01, max=1.58e+01, mean=-5.26e-10
#   Logits: min=-2.94e+01, max=1.09e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 144. IDs: ['1034-121119-29', '103-1240-10']
#   Input values: min=-1.85e+01, max=1.45e+01, mean=2.25e-10
#   Logits: min=-3.29e+01, max=1.25e+01, mean=-3.28e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 147. IDs: ['1034-121119-8', '1034-121119-90']
#   Input values: min=-9.01e+00, max=8.95e+00, mean=-8.07e-09
#   Logits: min=-3.28e+01, max=1.19e+01, mean=-3.19e+00, has_nan=False
# Epoch 2/5 - Avg Loss: 393.9622, Valid Batches: 108, NaN Batches: 42
# Epoch 3/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 3, Batch 0. IDs: ['1034-121119-19', '1034-121119-86']
#   Input values: min=-9.63e+00, max=9.22e+00, mean=6.93e-09
#   Logits: min=-3.24e+01, max=1.23e+01, mean=-3.34e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 5. IDs: ['103-1240-17', '1040-133433-38']
#   Input values: min=-1.53e+01, max=1.13e+01, mean=4.12e-10
#   Logits: min=-3.23e+01, max=1.19e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 13. IDs: ['1034-121119-90', '103-1240-0']
#   Input values: min=-1.13e+01, max=1.21e+01, mean=2.78e-09
#   Logits: min=-3.07e+01, max=1.22e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 15. IDs: ['103-1240-38', '103-1240-25']
#   Input values: min=-1.19e+01, max=8.14e+00, mean=1.92e-09
#   Logits: min=-3.06e+01, max=1.19e+01, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 21. IDs: ['103-1240-32', '1034-121119-36']
#   Input values: min=-2.09e+01, max=1.17e+01, mean=2.10e-10
#   Logits: min=-3.68e+01, max=1.40e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 23. IDs: ['1034-121119-65', '103-1241-11']
#   Input values: min=-1.59e+01, max=1.21e+01, mean=3.93e-09
#   Logits: min=-3.74e+01, max=1.48e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 29. IDs: ['1034-121119-24', '1034-121119-37']
#   Input values: min=-8.44e+00, max=1.64e+01, mean=-2.89e-09
#   Logits: min=-3.56e+01, max=1.47e+01, mean=-3.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 35. IDs: ['1040-133433-37', '103-1240-51']
#   Input values: min=-1.90e+01, max=1.21e+01, mean=-1.84e-09
#   Logits: min=-3.39e+01, max=1.31e+01, mean=-3.53e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 42. IDs: ['1040-133433-19', '103-1241-4']
#   Input values: min=-2.09e+01, max=1.70e+01, mean=2.16e-09
#   Logits: min=-3.10e+01, max=1.25e+01, mean=-3.34e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 48. IDs: ['1040-133433-10', '103-1241-25']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=-2.83e-09
#   Logits: min=-3.10e+01, max=9.50e+00, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 51. IDs: ['103-1241-26', '1040-133433-24']
#   Input values: min=-1.34e+01, max=1.14e+01, mean=1.95e-10
#   Logits: min=-2.78e+01, max=1.06e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 52. IDs: ['1040-133433-33', '1034-121119-22']
#   Input values: min=-1.05e+01, max=1.36e+01, mean=3.30e-10
#   Logits: min=-2.82e+01, max=9.22e+00, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 53. IDs: ['103-1241-41', '1034-121119-35']
#   Input values: min=-1.23e+01, max=1.25e+01, mean=2.37e-09
#   Logits: min=-3.23e+01, max=1.19e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 60. IDs: ['1034-121119-88', '1040-133433-51']
#   Input values: min=-1.33e+01, max=1.61e+01, mean=3.06e-09
#   Logits: min=-2.84e+01, max=8.90e+00, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 62. IDs: ['103-1240-40', '1034-121119-21']
#   Input values: min=-1.45e+01, max=1.09e+01, mean=-1.02e-09
#   Logits: min=-2.91e+01, max=1.14e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 63. IDs: ['1034-121119-41', '1034-121119-66']
#   Input values: min=-1.62e+01, max=1.39e+01, mean=5.21e-09
#   Logits: min=-2.63e+01, max=8.16e+00, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 65. IDs: ['103-1240-29', '1034-121119-92']
#   Input values: min=-1.39e+01, max=8.67e+00, mean=-1.56e-09
#   Logits: min=-3.00e+01, max=1.10e+01, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 68. IDs: ['103-1240-10', '1040-133433-21']
#   Input values: min=-1.85e+01, max=1.45e+01, mean=-3.66e-10
#   Logits: min=-3.16e+01, max=1.16e+01, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 71. IDs: ['1034-121119-46', '103-1240-46']
#   Input values: min=-1.51e+01, max=9.70e+00, mean=-9.74e-10
#   Logits: min=-2.77e+01, max=1.08e+01, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 75. IDs: ['1040-133433-49', '1034-121119-12']
#   Input values: min=-1.22e+01, max=1.51e+01, mean=1.01e-10
#   Logits: min=-2.94e+01, max=1.02e+01, mean=-2.98e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 76. IDs: ['103-1240-27', '1040-133433-18']
#   Input values: min=-1.58e+01, max=1.80e+01, mean=3.51e-09
#   Logits: min=-3.33e+01, max=1.39e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 81. IDs: ['1034-121119-76', '1040-133433-67']
#   Input values: min=-1.92e+01, max=1.93e+01, mean=3.88e-10
#   Logits: min=-2.98e+01, max=1.12e+01, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 85. IDs: ['103-1241-39', '1040-133433-69']
#   Input values: min=-1.56e+01, max=1.05e+01, mean=-1.98e-09
#   Logits: min=-3.45e+01, max=1.28e+01, mean=-2.99e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 86. IDs: ['1040-133433-76', '1034-121119-93']
#   Input values: min=-1.58e+01, max=1.59e+01, mean=-3.22e-10
#   Logits: min=-2.65e+01, max=8.38e+00, mean=-2.82e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 90. IDs: ['1069-133699-10', '1040-133433-70']
#   Input values: min=-1.21e+01, max=1.27e+01, mean=4.44e-10
#   Logits: min=-2.92e+01, max=9.01e+00, mean=-2.76e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 94. IDs: ['1069-133699-20', '1034-121119-54']
#   Input values: min=-9.61e+00, max=9.64e+00, mean=9.74e-10
#   Logits: min=-3.01e+01, max=1.04e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 95. IDs: ['103-1241-30', '1034-121119-42']
#   Input values: min=-1.35e+01, max=1.05e+01, mean=-3.85e-10
#   Logits: min=-3.09e+01, max=1.13e+01, mean=-2.96e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 99. IDs: ['1034-121119-29', '103-1241-0']
#   Input values: min=-1.87e+01, max=9.59e+00, mean=5.97e-11
#   Logits: min=-3.28e+01, max=1.23e+01, mean=-3.08e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 101. IDs: ['1040-133433-20', '103-1240-15']
#   Input values: min=-1.56e+01, max=1.20e+01, mean=1.04e-09
#   Logits: min=-3.20e+01, max=1.37e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 102. IDs: ['1034-121119-58', '1034-121119-89']
#   Input values: min=-8.97e+00, max=1.10e+01, mean=1.35e-09
#   Logits: min=-3.20e+01, max=1.19e+01, mean=-2.98e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 104. IDs: ['103-1240-21', '1034-121119-17']
#   Input values: min=-1.54e+01, max=1.23e+01, mean=-2.80e-09
#   Logits: min=-6.37e+01, max=1.99e+01, mean=-3.20e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 108. IDs: ['1069-133699-9', '103-1240-11']
#   Input values: min=-1.25e+01, max=9.86e+00, mean=2.24e-09
#   Logits: min=-2.92e+01, max=1.15e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 110. IDs: ['1040-133433-17', '1040-133433-64']
#   Input values: min=-1.10e+01, max=1.18e+01, mean=-7.40e-11
#   Logits: min=-3.21e+01, max=1.18e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 111. IDs: ['1040-133433-79', '103-1240-56']
#   Input values: min=-1.17e+01, max=1.23e+01, mean=3.41e-10
#   Logits: min=-3.08e+01, max=1.29e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 114. IDs: ['1034-121119-26', '103-1240-3']
#   Input values: min=-1.90e+01, max=1.28e+01, mean=-2.01e-09
#   Logits: min=-3.13e+01, max=1.20e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 120. IDs: ['1034-121119-67', '1040-133433-40']
#   Input values: min=-1.16e+01, max=1.63e+01, mean=-2.85e-09
#   Logits: min=-2.93e+01, max=1.09e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 122. IDs: ['103-1240-4', '1034-121119-9']
#   Input values: min=-1.30e+01, max=9.02e+00, mean=8.57e-10
#   Logits: min=-3.18e+01, max=1.38e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 132. IDs: ['1040-133433-14', '1034-121119-10']
#   Input values: min=-1.39e+01, max=1.57e+01, mean=2.01e-09
#   Logits: min=-2.96e+01, max=1.07e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 139. IDs: ['1040-133433-72', '1040-133433-66']
#   Input values: min=-1.17e+01, max=1.85e+01, mean=6.25e-10
#   Logits: min=-3.01e+01, max=1.10e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 146. IDs: ['103-1241-13', '1034-121119-80']
#   Input values: min=-1.65e+01, max=8.91e+00, mean=5.15e-10
#   Logits: min=-3.40e+01, max=1.29e+01, mean=-3.36e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 149. IDs: ['103-1240-24', '1034-121119-18']
#   Input values: min=-1.20e+01, max=9.91e+00, mean=1.65e-09
#   Logits: min=-3.58e+01, max=1.43e+01, mean=-3.36e+00, has_nan=False
# Epoch 3/5 - Avg Loss: 372.6588, Valid Batches: 109, NaN Batches: 41
# Epoch 4/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 4, Batch 2. IDs: ['1040-133433-61', '1034-121119-41']
#   Input values: min=-1.52e+01, max=1.90e+01, mean=-2.37e-09
#   Logits: min=-2.80e+01, max=9.42e+00, mean=-3.12e+00, has_nan=False
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x79690c34b380>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x79690c34b380>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1601, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# NaN/Inf loss detected! Epoch 4, Batch 10. IDs: ['1034-121119-80', '1040-133433-34']
#   Input values: min=-1.01e+01, max=1.26e+01, mean=1.53e-09
#   Logits: min=-3.34e+01, max=9.89e+00, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 23. IDs: ['1034-121119-6', '1034-121119-60']
#   Input values: min=-1.61e+01, max=1.05e+01, mean=-8.48e-09
#   Logits: min=-2.98e+01, max=1.01e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 26. IDs: ['103-1240-16', '1040-133433-48']
#   Input values: min=-2.53e+01, max=1.68e+01, mean=3.68e-09
#   Logits: min=-3.06e+01, max=1.09e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 38. IDs: ['1034-121119-18', '103-1241-36']
#   Input values: min=-1.26e+01, max=8.26e+00, mean=6.89e-10
#   Logits: min=-4.92e+01, max=1.95e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 41. IDs: ['1034-121119-29', '103-1241-32']
#   Input values: min=-1.30e+01, max=9.05e+00, mean=2.17e-10
#   Logits: min=-3.12e+01, max=1.08e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 45. IDs: ['1040-133433-79', '103-1240-56']
#   Input values: min=-1.17e+01, max=1.23e+01, mean=3.41e-10
#   Logits: min=-3.07e+01, max=1.07e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 47. IDs: ['1034-121119-59', '1040-133433-8']
#   Input values: min=-1.22e+01, max=1.24e+01, mean=-8.08e-10
#   Logits: min=-3.15e+01, max=1.01e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 50. IDs: ['1034-121119-22', '1040-133433-2']
#   Input values: min=-1.32e+01, max=1.58e+01, mean=-1.84e-09
#   Logits: min=-2.86e+01, max=9.02e+00, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 52. IDs: ['1040-133433-19', '103-1240-34']
#   Input values: min=-1.67e+01, max=1.70e+01, mean=-1.82e-10
#   Logits: min=-2.96e+01, max=1.23e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 56. IDs: ['1034-121119-0', '103-1240-52']
#   Input values: min=-1.85e+01, max=1.27e+01, mean=-9.67e-10
#   Logits: min=-3.06e+01, max=1.07e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 58. IDs: ['1034-121119-7', '1040-133433-66']
#   Input values: min=-8.29e+00, max=8.74e+00, mean=1.83e-09
#   Logits: min=-3.54e+01, max=1.34e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 61. IDs: ['1040-133433-55', '1069-133699-9']
#   Input values: min=-1.23e+01, max=1.70e+01, mean=-3.34e-10
#   Logits: min=-3.78e+01, max=1.51e+01, mean=-3.13e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 64. IDs: ['103-1241-7', '1034-121119-42']
#   Input values: min=-1.90e+01, max=1.11e+01, mean=-4.25e-09
#   Logits: min=-3.16e+01, max=1.17e+01, mean=-3.20e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 69. IDs: ['1034-121119-21', '103-1241-29']
#   Input values: min=-1.09e+01, max=9.38e+00, mean=1.03e-09
#   Logits: min=-5.51e+01, max=1.87e+01, mean=-3.34e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 71. IDs: ['1034-121119-87', '1034-121119-10']
#   Input values: min=-9.98e+00, max=9.80e+00, mean=2.70e-09
#   Logits: min=-2.99e+01, max=1.02e+01, mean=-3.08e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 73. IDs: ['1040-133433-27', '103-1240-15']
#   Input values: min=-1.56e+01, max=1.28e+01, mean=4.21e-09
#   Logits: min=-3.06e+01, max=9.87e+00, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 79. IDs: ['1040-133433-6', '103-1241-41']
#   Input values: min=-1.23e+01, max=1.25e+01, mean=1.85e-09
#   Logits: min=-3.13e+01, max=1.25e+01, mean=-3.17e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 81. IDs: ['1034-121119-90', '1034-121119-12']
#   Input values: min=-9.06e+00, max=8.70e+00, mean=3.88e-09
#   Logits: min=-3.07e+01, max=1.19e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 83. IDs: ['103-1240-38', '1034-121119-14']
#   Input values: min=-1.19e+01, max=1.13e+01, mean=4.39e-09
#   Logits: min=-4.45e+01, max=1.59e+01, mean=-3.27e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 90. IDs: ['103-1241-3', '1034-121119-77']
#   Input values: min=-1.67e+01, max=9.63e+00, mean=1.13e-09
#   Logits: min=-4.67e+01, max=1.72e+01, mean=-3.43e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 91. IDs: ['1040-133433-70', '1034-121119-40']
#   Input values: min=-1.26e+01, max=1.27e+01, mean=2.31e-09
#   Logits: min=-2.64e+01, max=8.89e+00, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 95. IDs: ['1034-121119-46', '1034-121119-50']
#   Input values: min=-8.25e+00, max=1.22e+01, mean=-7.43e-09
#   Logits: min=-2.57e+01, max=7.30e+00, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 97. IDs: ['1040-133433-18', '103-1241-5']
#   Input values: min=-1.58e+01, max=1.80e+01, mean=-2.15e-09
#   Logits: min=-3.10e+01, max=1.01e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 101. IDs: ['1034-121119-38', '1034-121119-33']
#   Input values: min=-9.59e+00, max=9.23e+00, mean=2.03e-09
#   Logits: min=-3.17e+01, max=1.11e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 103. IDs: ['103-1241-13', '103-1241-19']
#   Input values: min=-1.65e+01, max=1.16e+01, mean=9.26e-10
#   Logits: min=-3.67e+01, max=1.18e+01, mean=-3.24e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 104. IDs: ['1034-121119-52', '1034-121119-84']
#   Input values: min=-1.17e+01, max=1.14e+01, mean=1.47e-09
#   Logits: min=-2.96e+01, max=1.05e+01, mean=-3.17e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 108. IDs: ['103-1240-42', '1040-133433-51']
#   Input values: min=-1.41e+01, max=1.61e+01, mean=5.16e-09
#   Logits: min=-4.51e+01, max=1.96e+01, mean=-3.52e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 117. IDs: ['1034-121119-26', '1040-133433-64']
#   Input values: min=-9.87e+00, max=1.18e+01, mean=-8.83e-11
#   Logits: min=-2.59e+01, max=7.20e+00, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 122. IDs: ['1040-133433-36', '1034-121119-89']
#   Input values: min=-1.27e+01, max=1.23e+01, mean=2.77e-09
#   Logits: min=-2.90e+01, max=1.12e+01, mean=-3.17e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 124. IDs: ['1034-121119-36', '1034-121119-56']
#   Input values: min=-8.83e+00, max=1.18e+01, mean=-3.41e-10
#   Logits: min=-3.04e+01, max=1.06e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 125. IDs: ['103-1241-25', '103-1240-17']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=-7.00e-10
#   Logits: min=-3.39e+01, max=1.22e+01, mean=-3.29e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 129. IDs: ['103-1240-46', '1040-133433-24']
#   Input values: min=-1.51e+01, max=1.14e+01, mean=-3.38e-10
#   Logits: min=-3.11e+01, max=1.29e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 134. IDs: ['1040-133433-59', '1034-121119-24']
#   Input values: min=-1.07e+01, max=1.70e+01, mean=3.09e-10
#   Logits: min=-2.84e+01, max=1.11e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 135. IDs: ['1034-121119-93', '1034-121119-91']
#   Input values: min=-1.03e+01, max=1.19e+01, mean=1.54e-09
#   Logits: min=-3.23e+01, max=1.11e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 138. IDs: ['1040-133433-38', '1034-121119-3']
#   Input values: min=-1.45e+01, max=1.13e+01, mean=1.60e-08
#   Logits: min=-3.51e+01, max=1.30e+01, mean=-3.38e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 139. IDs: ['103-1241-11', '1034-121119-92']
#   Input values: min=-1.59e+01, max=1.21e+01, mean=-6.83e-10
#   Logits: min=-3.65e+01, max=1.54e+01, mean=-3.33e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 146. IDs: ['1040-133433-50', '1034-121119-9']
#   Input values: min=-1.78e+01, max=1.72e+01, mean=2.51e-09
#   Logits: min=-2.94e+01, max=1.08e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 147. IDs: ['1040-133433-71', '1034-121119-35']
#   Input values: min=-9.71e+00, max=1.31e+01, mean=1.76e-09
#   Logits: min=-3.12e+01, max=1.17e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 149. IDs: ['1040-133433-21', '103-1240-29']
#   Input values: min=-1.39e+01, max=8.67e+00, mean=-1.92e-09
#   Logits: min=-3.24e+01, max=1.17e+01, mean=-3.20e+00, has_nan=False
# Epoch 4/5 - Avg Loss: 437.4268, Valid Batches: 110, NaN Batches: 40
# Epoch 5/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 5, Batch 0. IDs: ['1069-133699-1', '1034-121119-35']
#   Input values: min=-1.04e+01, max=1.04e+01, mean=3.01e-11
#   Logits: min=-3.07e+01, max=1.14e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 2. IDs: ['1040-133433-43', '1040-133433-26']
#   Input values: min=-1.33e+01, max=1.61e+01, mean=-2.17e-09
#   Logits: min=-2.99e+01, max=1.01e+01, mean=-3.34e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 4. IDs: ['1040-133433-15', '1040-133433-70']
#   Input values: min=-1.60e+01, max=1.66e+01, mean=-7.58e-10
#   Logits: min=-2.77e+01, max=1.03e+01, mean=-3.12e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 11. IDs: ['1040-133433-65', '103-1241-25']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=-7.89e-10
#   Logits: min=-2.73e+01, max=9.38e+00, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 12. IDs: ['1034-121119-55', '1040-133433-38']
#   Input values: min=-8.41e+00, max=1.13e+01, mean=1.33e-08
#   Logits: min=-3.07e+01, max=1.13e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 13. IDs: ['103-1241-42', '1034-121119-9']
#   Input values: min=-1.46e+01, max=8.77e+00, mean=1.33e-10
#   Logits: min=-3.36e+01, max=1.03e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 20. IDs: ['1040-133433-18', '103-1241-3']
#   Input values: min=-1.67e+01, max=1.80e+01, mean=2.06e-09
#   Logits: min=-3.22e+01, max=1.07e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 26. IDs: ['1034-121119-93', '103-1241-31']
#   Input values: min=-2.39e+01, max=1.85e+01, mean=3.92e-09
#   Logits: min=-3.09e+01, max=9.70e+00, mean=-2.96e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 29. IDs: ['1040-133433-33', '1034-121119-12']
#   Input values: min=-9.70e+00, max=1.36e+01, mean=2.09e-09
#   Logits: min=-2.69e+01, max=9.93e+00, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 31. IDs: ['1040-133433-6', '1034-121119-48']
#   Input values: min=-1.13e+01, max=1.11e+01, mean=1.93e-09
#   Logits: min=-3.27e+01, max=1.35e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 32. IDs: ['1034-121119-77', '103-1241-10']
#   Input values: min=-1.17e+01, max=8.24e+00, mean=7.92e-10
#   Logits: min=-3.22e+01, max=1.21e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 36. IDs: ['1069-133699-9', '1040-133433-60']
#   Input values: min=-1.22e+01, max=2.08e+01, mean=2.89e-09
#   Logits: min=-2.40e+01, max=8.24e+00, mean=-2.79e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 37. IDs: ['103-1241-33', '1034-121119-78']
#   Input values: min=-1.65e+01, max=8.39e+00, mean=-1.24e-09
#   Logits: min=-3.35e+01, max=1.30e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 44. IDs: ['103-1240-20', '1034-121119-22']
#   Input values: min=-1.20e+01, max=8.38e+00, mean=-1.40e-09
#   Logits: min=-3.34e+01, max=1.29e+01, mean=-3.12e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 48. IDs: ['1040-133433-64', '103-1241-4']
#   Input values: min=-2.09e+01, max=1.18e+01, mean=1.17e-09
#   Logits: min=-4.89e+01, max=1.87e+01, mean=-3.60e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 51. IDs: ['103-1241-17', '1034-121119-89']
#   Input values: min=-1.86e+01, max=1.10e+01, mean=-2.33e-09
#   Logits: min=-3.39e+01, max=1.26e+01, mean=-3.33e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 57. IDs: ['1034-121119-26', '103-1240-7']
#   Input values: min=-1.57e+01, max=1.11e+01, mean=-6.03e-10
#   Logits: min=-3.44e+01, max=1.36e+01, mean=-3.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 60. IDs: ['1034-121119-86', '103-1240-51']
#   Input values: min=-1.90e+01, max=1.21e+01, mean=-1.05e-09
#   Logits: min=-3.39e+01, max=1.35e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 62. IDs: ['1034-121119-18', '103-1240-23']
#   Input values: min=-1.61e+01, max=1.43e+01, mean=-2.85e-09
#   Logits: min=-5.01e+01, max=2.14e+01, mean=-3.48e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 64. IDs: ['1034-121119-62', '1034-121119-24']
#   Input values: min=-1.13e+01, max=1.24e+01, mean=3.37e-09
#   Logits: min=-3.19e+01, max=1.09e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 69. IDs: ['103-1241-5', '1034-121119-59']
#   Input values: min=-1.39e+01, max=1.14e+01, mean=-9.52e-10
#   Logits: min=-3.56e+01, max=1.46e+01, mean=-3.55e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 73. IDs: ['1040-133433-66', '1040-133433-13']
#   Input values: min=-1.58e+01, max=1.88e+01, mean=3.43e-10
#   Logits: min=-3.01e+01, max=1.06e+01, mean=-3.27e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 75. IDs: ['103-1240-37', '1034-121119-76']
#   Input values: min=-2.37e+01, max=2.33e+01, mean=-6.84e-10
#   Logits: min=-3.49e+01, max=1.66e+01, mean=-3.43e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 77. IDs: ['1040-133433-21', '103-1241-23']
#   Input values: min=-3.26e+01, max=1.92e+01, mean=3.00e-09
#   Logits: min=-3.20e+01, max=1.27e+01, mean=-3.25e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 79. IDs: ['1034-121119-5', '1034-121119-84']
#   Input values: min=-9.42e+00, max=9.69e+00, mean=0.00e+00
#   Logits: min=-3.33e+01, max=1.36e+01, mean=-3.41e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 80. IDs: ['1034-121119-57', '1034-121119-38']
#   Input values: min=-1.20e+01, max=9.00e+00, mean=7.08e-09
#   Logits: min=-5.60e+01, max=1.79e+01, mean=-3.54e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 81. IDs: ['103-1240-11', '1040-133433-48']
#   Input values: min=-1.25e+01, max=1.68e+01, mean=1.87e-09
#   Logits: min=-3.64e+01, max=1.44e+01, mean=-3.43e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 87. IDs: ['1040-133433-37', '103-1240-15']
#   Input values: min=-1.56e+01, max=9.07e+00, mean=-3.50e-09
#   Logits: min=-2.83e+01, max=1.09e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 90. IDs: ['1040-133433-28', '1040-133433-24']
#   Input values: min=-1.08e+01, max=1.49e+01, mean=-2.28e-10
#   Logits: min=-2.94e+01, max=9.61e+00, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 94. IDs: ['1034-121119-20', '1040-133433-69']
#   Input values: min=-9.40e+00, max=1.05e+01, mean=3.42e-10
#   Logits: min=-2.74e+01, max=1.04e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 108. IDs: ['1034-121119-17', '1034-121119-1']
#   Input values: min=-1.21e+01, max=1.10e+01, mean=2.93e-10
#   Logits: min=-2.91e+01, max=9.17e+00, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 110. IDs: ['103-1240-26', '1034-121119-88']
#   Input values: min=-2.02e+01, max=1.57e+01, mean=5.43e-10
#   Logits: min=-2.86e+01, max=8.93e+00, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 112. IDs: ['1034-121119-50', '1040-133433-78']
#   Input values: min=-8.25e+00, max=1.22e+01, mean=-8.05e-09
#   Logits: min=-2.48e+01, max=8.09e+00, mean=-2.96e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 113. IDs: ['1034-121119-90', '1069-133699-19']
#   Input values: min=-1.08e+01, max=8.90e+00, mean=2.42e-09
#   Logits: min=-2.86e+01, max=1.10e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 116. IDs: ['1034-121119-80', '1034-121119-95']
#   Input values: min=-9.56e+00, max=1.09e+01, mean=1.32e-08
#   Logits: min=-3.88e+01, max=1.33e+01, mean=-3.12e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 120. IDs: ['1034-121119-29', '103-1240-5']
#   Input values: min=-1.27e+01, max=8.57e+00, mean=-8.96e-10
#   Logits: min=-3.24e+01, max=1.19e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 123. IDs: ['103-1240-13', '1034-121119-67']
#   Input values: min=-2.04e+01, max=8.90e+00, mean=4.06e-10
#   Logits: min=-3.15e+01, max=1.20e+01, mean=-3.25e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 124. IDs: ['1034-121119-41', '1069-133699-3']
#   Input values: min=-8.42e+00, max=9.82e+00, mean=1.81e-10
#   Logits: min=-3.12e+01, max=1.09e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 125. IDs: ['103-1240-3', '1034-121119-65']
#   Input values: min=-1.90e+01, max=1.28e+01, mean=2.12e-09
#   Logits: min=-3.15e+01, max=9.96e+00, mean=-3.25e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 127. IDs: ['1034-121119-21', '103-1240-8']
#   Input values: min=-1.39e+01, max=1.00e+01, mean=-3.22e-09
#   Logits: min=-3.16e+01, max=1.09e+01, mean=-3.24e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 131. IDs: ['1040-133433-39', '103-1241-19']
#   Input values: min=-1.45e+01, max=1.28e+01, mean=1.32e-10
#   Logits: min=-4.00e+01, max=1.93e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 137. IDs: ['103-1240-41', '1034-121119-46']
#   Input values: min=-1.46e+01, max=1.03e+01, mean=-3.57e-10
#   Logits: min=-3.06e+01, max=1.13e+01, mean=-3.20e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 143. IDs: ['1040-133433-29', '1034-121119-42']
#   Input values: min=-1.95e+01, max=1.78e+01, mean=-2.65e-09
#   Logits: min=-2.74e+01, max=8.51e+00, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 148. IDs: ['1040-133433-25', '1040-133433-54']
#   Input values: min=-1.23e+01, max=1.69e+01, mean=2.21e-10
#   Logits: min=-2.81e+01, max=8.45e+00, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 149. IDs: ['1040-133433-19', '103-1241-1']
#   Input values: min=-2.78e+01, max=1.70e+01, mean=4.60e-09
#   Logits: min=-3.15e+01, max=1.05e+01, mean=-3.32e+00, has_nan=False
# Epoch 5/5 - Avg Loss: 380.2111, Valid Batches: 105, NaN Batches: 45
#
# Saving fine-tuned model and processor to ./wav2vec2_librispeech_finetuned...
# Training complete and model saved.

# %%
pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.2.0)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading jiwer-3.1.0-py3-none-any.whl (22 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.1.0 rapidfuzz-3.13.0

# %%
# --- 9. Simple Inference Example ---
# Check for either pytorch_model.bin or model.safetensors
model_weights_name_bin = "pytorch_model.bin"
model_weights_name_sf = "model.safetensors" # Standard name for safetensors weights

model_path_bin = os.path.join(OUTPUT_DIR, model_weights_name_bin)
model_path_sf = os.path.join(OUTPUT_DIR, model_weights_name_sf)

if os.path.exists(model_path_bin) or os.path.exists(model_path_sf):
    print("\n--- Inference Example ---")
    try:
        # Wav2Vec2ForCTC.from_pretrained will automatically find the correct weights file
        model_inf = Wav2Vec2ForCTC.from_pretrained(OUTPUT_DIR).to(DEVICE)
        processor_inf = Wav2Vec2Processor.from_pretrained(OUTPUT_DIR)
        model_inf.eval()

        # Your logic to select a sample
        print(f"Length of processed_dataset: {len(processed_dataset)}") # Original print
        # The original code directly picks from test_dataset.torchaudio_dataset
        # Let's stick to that for consistency with the provided snippet.
        sample_idx = 567 # As per your code
        if sample_idx >= len(test_dataset.torchaudio_dataset):
            print(f"Warning: Sample index {sample_idx} is out of bounds for test_dataset. Using index 0.")
            sample_idx = 5
            if len(test_dataset.torchaudio_dataset) == 0:
                raise ValueError("test_dataset.torchaudio_dataset is empty!")


        sample_candidate = test_dataset.torchaudio_dataset[sample_idx]
        waveform_orig, sr_orig, original_transcript, speaker_id, chapter_id, utterance_id = sample_candidate
        inference_sample_data = sample_candidate # Assuming this sample is always valid for the example

        if inference_sample_data:
            waveform_orig, sr_orig, original_transcript, speaker_id, chapter_id, utterance_id = inference_sample_data
            print(f"\nOriginal transcript (ID: {speaker_id}-{chapter_id}-{utterance_id}):")
            print(original_transcript)

            # Resample if necessary
            target_sr_inf = processor_inf.feature_extractor.sampling_rate
            if sr_orig != target_sr_inf:
                print(f"Resampling waveform from {sr_orig} Hz to {target_sr_inf} Hz.")
                resampler = torchaudio.transforms.Resample(orig_freq=sr_orig, new_freq=target_sr_inf)
                waveform_orig_resampled = resampler(waveform_orig)
            else:
                waveform_orig_resampled = waveform_orig

            # Squeeze and check dimensions
            waveform_squeezed_orig = waveform_orig_resampled.squeeze(0)
            if waveform_squeezed_orig.ndim == 0:
                 raise ValueError("Waveform for inference became a scalar.")
            if waveform_squeezed_orig.ndim > 1 : # Ensure it's 1D
                if waveform_squeezed_orig.shape[0] == 1: # like (1, N) after squeeze from (1,1,N)
                    waveform_squeezed_orig = waveform_squeezed_orig.squeeze(0)
                else: # Potentially (C, N) for stereo - ASR models usually expect mono
                    print(f"Warning: Waveform has {waveform_squeezed_orig.shape[0]} channels. Taking the first channel.")
                    waveform_squeezed_orig = waveform_squeezed_orig[0]


            # Process for inference
            # The processor expects a 1D array or list of floats
            input_dict = processor_inf(
                waveform_squeezed_orig.numpy(), # Processor usually expects numpy array or list of floats
                return_tensors="pt",
                sampling_rate=target_sr_inf,
                padding=True
            )
            input_values_inf = input_dict.input_values.to(DEVICE)
            attention_mask_inf = input_dict.attention_mask.to(DEVICE) if hasattr(input_dict, 'attention_mask') and input_dict.attention_mask is not None else None

            with torch.no_grad():
                logits_inf = model_inf(input_values_inf, attention_mask=attention_mask_inf).logits

            predicted_ids = torch.argmax(logits_inf, dim=-1)
            # `batch_decode` handles joining tokens and some cleanup.
            # The output is usually uppercase and with certain punctuation removed/normalized.
            predicted_sentence = processor_inf.batch_decode(predicted_ids)[0]
            print(f"\nPredicted transcript:")
            print(predicted_sentence)

            # --- METRIC CALCULATION ---
            try:
                import jiwer
                import re

                # Normalization function:
                # Wav2Vec2 models are often trained on uppercase text with minimal punctuation.
                # The processor.batch_decode() output is typically already normalized (e.g. uppercase).
                # We need to apply similar normalization to the original_transcript for a fair comparison.
                def normalize_text_for_asr_metrics(text):
                    text = str(text).upper() # Convert to uppercase
                    # Remove common punctuation. This list can be expanded.
                    # Consider what punctuation your model is expected to handle or ignore.
                    # For LibriSpeech, transcripts are typically clean.
                    punctuation_to_remove = r"[.,?!-;:]" # Add others like quotes if needed: r"[.,?!-;:“”\"]"
                    text = re.sub(punctuation_to_remove, "", text)
                    text = text.replace("-", " ") # Treat hyphens as spaces or remove if tokenizer does
                    text = " ".join(text.split()) # Normalize whitespace (remove multiple spaces, trim)
                    return text

                # Normalize both original and predicted transcripts
                # `predicted_sentence` from `batch_decode` is often already quite clean/normalized.
                # Applying the same normalization ensures consistency.
                normalized_original = normalize_text_for_asr_metrics(original_transcript)
                normalized_predicted = normalize_text_for_asr_metrics(predicted_sentence)

                print(f"\n--- Metrics Calculation ---")
                print(f"Normalized Original: '{normalized_original}'")
                print(f"Normalized Predicted: '{normalized_predicted}'")

                if not normalized_original: # Handle cases where original transcript becomes empty
                    print("Warning: Normalized original transcript is empty. Metrics might be misleading.")
                    wer = float('inf') if normalized_predicted else 0.0 # If pred is also empty, 0 error
                    cer = float('inf') if normalized_predicted else 0.0
                else:
                    wer = jiwer.wer(normalized_original, normalized_predicted)
                    cer = jiwer.cer(normalized_original, normalized_predicted)

                print(f"Word Error Rate (WER): {wer:.4f}")
                print(f"Character Error Rate (CER): {cer:.4f}")

            except ImportError:
                print("\n[METRICS] Please install jiwer for metrics calculation: pip install jiwer")
            except Exception as e_metric:
                print(f"[METRICS] Error during metric calculation: {e_metric}")
                import traceback
                traceback.print_exc()
            # --- END OF METRIC CALCULATION ---

        else:
            print("Not enough valid samples in the dataset to run inference example.")
            # The original print was:
            # print(f"(Checked {len(processed_dataset)} entries in processed_dataset for a suitable sample).")
            # This seems mismatched with how the sample was actually selected above (directly from test_dataset).
            # For clarity, if inference_sample_data can be None based on other logic:
            print(f"No suitable inference_sample_data found.")


    except Exception as e:
        print(f"Error during inference example: {e}")
        import traceback
        traceback.print_exc()
else:
    print(f"\nInference example skipped as model weights ('{model_weights_name_bin}' or '{model_weights_name_sf}') not found in {OUTPUT_DIR}.")

print("\nScript finished.")
# Out:
# --- Inference Example ---
# Length of processed_dataset: 300
#
# Original transcript (ID: 1088-134315-19):
# HE RANG THE BELL THIS TIME FOR HIS VALET FISHER HE SAID I AM EXPECTING A VISIT FROM A GENTLEMAN NAMED GATHERCOLE A ONE ARMED GENTLEMAN WHOM YOU MUST LOOK AFTER IF HE COMES
#
# Predicted transcript:
# HE RANG THE BELL THIS TIME FOR HIS VALET FISHER HE SAID I AM EXPECTING A VISIT FROM A GENTLEMAN NAMED GATHERCOL A ONE ARMED GENTLEMAN WHOM YOU MUST LOOK AFTER IF HE COMES
#
# --- Metrics Calculation ---
# Normalized Original: 'HE RANG THE BELL THIS TIME FOR HIS VALET FISHER HE SAID I AM EXPECTING A VISIT FROM A GENTLEMAN NAMED GATHERCOLE A ONE ARMED GENTLEMAN WHOM YOU MUST LOOK AFTER IF HE COMES'
# Normalized Predicted: 'HE RANG THE BELL THIS TIME FOR HIS VALET FISHER HE SAID I AM EXPECTING A VISIT FROM A GENTLEMAN NAMED GATHERCOL A ONE ARMED GENTLEMAN WHOM YOU MUST LOOK AFTER IF HE COMES'
# Word Error Rate (WER): 0.0294
# Character Error Rate (CER): 0.0058
#
# Script finished.

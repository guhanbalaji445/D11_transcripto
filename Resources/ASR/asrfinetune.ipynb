# %%
import os
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor, AutoConfig
from torch.optim import AdamW
from tqdm.auto import tqdm
import numpy as np

# --- Configuration ---
MODEL_NAME = "facebook/wav2vec2-base-960h"
DATA_ROOT = "./data_librispeech_asr"
OUTPUT_DIR = "./wav2vec2_librispeech_finetuned"
NUM_EPOCHS = 5
BATCH_SIZE = 2
LEARNING_RATE = 3e-5
GRAD_CLIP_NORM = 1.0
MAX_SAMPLES = 300
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Using device: {DEVICE}")
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

# --- 1. Load Pre-trained Model, Processor and Config ---
print(f"Loading model, processor, and config for: {MODEL_NAME}...")
processor = Wav2Vec2Processor.from_pretrained(MODEL_NAME)
model_config = AutoConfig.from_pretrained(MODEL_NAME)
model = Wav2Vec2ForCTC.from_pretrained(MODEL_NAME)
model.to(DEVICE)
model.freeze_feature_encoder()

# --- 1.5 Verify Critical Tokenizer and Model Config ---
print("\n--- Verifying Tokenizer and Model Config ---")
if model.config.pad_token_id != processor.tokenizer.pad_token_id:
    print(f"CRITICAL WARNING: Model's pad_token_id ({model.config.pad_token_id}) and "
          f"Processor's pad_token_id ({processor.tokenizer.pad_token_id}) DO NOT MATCH!")
    print("This will likely lead to incorrect CTC behavior. Ensure they are aligned.")
else:
    print(f"Model CTC Blank ID (model.config.pad_token_id): {model.config.pad_token_id}")
    print(f"Processor Padding ID (processor.tokenizer.pad_token_id): {processor.tokenizer.pad_token_id}")
    print("Pad token IDs match. OK.")
print(f"Model inputs_to_logits_ratio: {model_config.inputs_to_logits_ratio}")
print("--- End Verification ---\n")

# --- 2. Load Dataset ---
print("Loading LibriSpeech dataset...")
try:
    librispeech_dataset_full = torchaudio.datasets.LIBRISPEECH(
        root=DATA_ROOT,
        url="train-clean-100",
        download=True
    )
except Exception as e:
    print(f"Error downloading/loading LibriSpeech. If it's a checksum error, try deleting the downloaded archive in {DATA_ROOT}/LibriSpeech and re-running.")
    print(f"Details: {e}")
    exit()

class SubsetDataset(Dataset):
    def __init__(self, full_dataset, num_samples):
        self.full_dataset = full_dataset
        self.indices = list(range(min(num_samples, len(full_dataset))))

    def __getitem__(self, idx):
        return self.full_dataset[self.indices[idx]]

    def __len__(self):
        return len(self.indices)

dataset = SubsetDataset(librispeech_dataset_full, MAX_SAMPLES)
print(f"Using {len(dataset)} samples for training.")

# --- 3. Custom PyTorch Dataset for Preprocessing ---
class AudioDataset(Dataset):
    def __init__(self, torchaudio_dataset, processor, target_sample_rate=16000):
        self.torchaudio_dataset = torchaudio_dataset
        self.processor = processor
        self.target_sample_rate = target_sample_rate
        self.inputs_to_logits_ratio = model_config.inputs_to_logits_ratio

    def __len__(self):
        return len(self.torchaudio_dataset)

    def __getitem__(self, idx):
        try:
            waveform, sample_rate, utterance, speaker_id, chapter_id, utterance_id = self.torchaudio_dataset[idx]
        except Exception:
            return None

        if not utterance.strip():
            return None

        if sample_rate != self.target_sample_rate:
            resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=self.target_sample_rate)
            waveform = resampler(waveform)

        waveform_squeezed = waveform.squeeze(0)
        if waveform_squeezed.ndim == 0:
            return None

        if waveform_squeezed.shape[0] < self.inputs_to_logits_ratio:
            return None

        input_values = self.processor(
            waveform_squeezed,
            sampling_rate=self.target_sample_rate,
            return_tensors="pt"
        ).input_values.squeeze(0)

        # Process transcript for labels (removed `as_target_processor` context)
        labels_dict = self.processor.tokenizer(
            utterance.upper(),
            return_tensors="pt",
            padding=False,
            truncation=False,
            add_special_tokens=False
        )
        labels = labels_dict.input_ids.squeeze(0)

        if labels.nelement() == 0:
            return None

        expected_logits_len = waveform_squeezed.shape[0] // self.inputs_to_logits_ratio
        if expected_logits_len < labels.shape[0]:
            return None

        return {
            "input_values": input_values,
            "labels": labels,
            "id": f"{speaker_id}-{chapter_id}-{utterance_id}",
            "waveform_len_debug": waveform_squeezed.shape[0],
            "label_len_debug": labels.shape[0]
        }

processed_dataset = AudioDataset(dataset, processor)
test_dataset = AudioDataset(librispeech_dataset_full, processor)

# --- 4. Custom Data Collator ---
class CustomDataCollatorCTCWithPadding:
    def __init__(self, processor):
        self.processor = processor
        self.audio_padding_value = 0.0
        self.label_padding_token_id = self.processor.tokenizer.pad_token_id
        if self.label_padding_token_id is None:
            print("Warning: processor.tokenizer.pad_token_id is None. Defaulting label padding to 0.")
            self.label_padding_token_id = 0

    def __call__(self, features):
        valid_features = [f for f in features if f is not None]
        if not valid_features:
            return {}

        input_values_list = [feature["input_values"] for feature in valid_features]
        labels_list = [feature["labels"] for feature in valid_features]

        # Pad audio by passing a dictionary to feature_extractor.pad
        audio_to_pad = {"input_values": input_values_list}
        batch_padded_audio = self.processor.feature_extractor.pad(
            audio_to_pad, # Pass the dictionary
            padding=True,
            return_tensors="pt",
            pad_to_multiple_of=None,
            return_attention_mask=True  # Ensure mask is returned
        )

        # Pad labels
        max_label_len = max(len(lab) for lab in labels_list)
        padded_labels_list = []
        for lab in labels_list:
            padding_needed = max_label_len - len(lab)
            padded_lab = torch.cat([lab, torch.full((padding_needed,), self.label_padding_token_id, dtype=lab.dtype)], dim=0)
            padded_labels_list.append(padded_lab)
        batch_labels = torch.stack(padded_labels_list)

        batch_ids = [f.get("id", "unknown") for f in valid_features]
        waveform_lengths = [f.get("waveform_len_debug", 0) for f in valid_features]
        label_lengths = [f.get("label_len_debug", 0) for f in valid_features]

        return {
            "input_values": batch_padded_audio.input_values,
            "attention_mask": batch_padded_audio.attention_mask,
            "labels": batch_labels,
            "ids_debug": batch_ids,
            "waveform_lengths_debug": waveform_lengths,
            "label_lengths_debug": label_lengths
        }

data_collator = CustomDataCollatorCTCWithPadding(processor=processor)

train_dataloader = DataLoader(
    processed_dataset,
    batch_size=BATCH_SIZE,
    collate_fn=data_collator,
    shuffle=True,
    num_workers=2 # Set to 0 if you still face issues, to debug in main thread
)

# --- 5. Sanity Check Dataloader Output ---
print("\n--- Sanity Checking Dataloader Output ---")
num_valid_samples_in_processed_dataset = 0
for i in range(len(processed_dataset)):
    if processed_dataset[i] is not None:
        num_valid_samples_in_processed_dataset +=1
print(f"Total samples in original subset: {len(dataset)}")
print(f"Effective samples after AudioDataset filtering: {num_valid_samples_in_processed_dataset}")

if num_valid_samples_in_processed_dataset > 0:
    try:
        for i, batch_sanity in enumerate(train_dataloader):
            if i >= 1: break
            if not batch_sanity: print(f"Sanity check: Batch {i} is empty."); continue

            print(f"\nSanity Check Batch {i}:")
            print(f"  Input values shape: {batch_sanity['input_values'].shape}")
            print(f"  Attention mask shape: {batch_sanity['attention_mask'].shape}")
            print(f"  Labels shape: {batch_sanity['labels'].shape}")
            # Ensure labels tensor is not empty before decoding and accessing index 0
            if batch_sanity['labels'].numel() > 0 and len(batch_sanity['labels']) > 0:
                 print(f"  Sample 0 Decoded Labels (first 50 chars): '{processor.decode(batch_sanity['labels'][0].tolist())[:50]}'")
            else:
                print("  Sample 0 Labels are empty or not present for decoding.")

            if batch_sanity.get('waveform_lengths_debug') and len(batch_sanity['waveform_lengths_debug']) > 0:
                wf_len_s0 = batch_sanity['waveform_lengths_debug'][0]
                lbl_len_s0 = batch_sanity['label_lengths_debug'][0]
                exp_logits_s0 = wf_len_s0 // model_config.inputs_to_logits_ratio
                print(f"  Sample 0 CTC check: WF_len={wf_len_s0}, ExpLogits={exp_logits_s0}, Lbl_len={lbl_len_s0}. Valid: {exp_logits_s0 >= lbl_len_s0}")
                if not (exp_logits_s0 >= lbl_len_s0):
                    print(f"    WARNING: Sample 0 may fail CTC length constraint in model!")
            else:
                print("  Debug lengths not available for Sample 0.")
    except Exception as e:
        print(f"Error during dataloader sanity check: {e}")
        import traceback
        traceback.print_exc() # Print full traceback for dataloader errors
        print("This might indicate an issue with data processing or collation.")
else:
    print("Effective dataset size is 0. Cannot perform dataloader sanity check. Check filtering in AudioDataset.")
print("--- End Sanity Checking ---\n")

# --- 6. Optimizer ---
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)

# --- 7. Training Loop ---
print("Starting training...")
model.train()
avg_epoch_loss = float('nan') # Initialize in case no valid batches
num_valid_batches_epoch = 0   # Initialize

for epoch in range(NUM_EPOCHS):
    epoch_loss, num_valid_batches_epoch, num_nan_batches_epoch = 0, 0, 0
    progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for batch_idx, batch in enumerate(progress_bar):
        if not batch or "input_values" not in batch or batch["input_values"] is None:
            print(f"Skipping empty or invalid batch at epoch {epoch+1}, index {batch_idx}")
            continue

        optimizer.zero_grad()

        input_values = batch["input_values"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)

        try:
            outputs = model(input_values, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss

            if torch.isnan(loss) or torch.isinf(loss):
                num_nan_batches_epoch += 1
                print(f"\nNaN/Inf loss detected! Epoch {epoch+1}, Batch {batch_idx}. IDs: {batch.get('ids_debug', 'N/A')}")
                print(f"  Input values: min={input_values.min():.2e}, max={input_values.max():.2e}, mean={input_values.mean():.2e}")
                if hasattr(outputs, 'logits') and outputs.logits is not None:
                    print(f"  Logits: min={outputs.logits.min():.2e}, max={outputs.logits.max():.2e}, mean={outputs.logits.mean():.2e}, has_nan={torch.isnan(outputs.logits).any()}")
                for i in range(labels.size(0)):
                    current_labels = labels[i]
                    effective_label_length = (current_labels != processor.tokenizer.pad_token_id).sum().item()
                    if effective_label_length == 0 and model.config.ctc_zero_infinity is False:
                        print(f"  Sample {i} (ID: {batch.get('ids_debug', ['N/A']*labels.size(0))[i]}) has effective zero-length label. This can cause inf loss if ctc_zero_infinity=False.")
                optimizer.zero_grad(set_to_none=True)
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP_NORM)
            optimizer.step()

            epoch_loss += loss.item()
            num_valid_batches_epoch += 1
            progress_bar.set_postfix({"loss": loss.item(), "lr": optimizer.param_groups[0]['lr'], "nans": num_nan_batches_epoch})

        except Exception as e:
            print(f"\nError during model forward/backward pass at Epoch {epoch+1}, Batch {batch_idx}: {e}")
            print(f"  Input values shape: {input_values.shape}, attention_mask shape: {attention_mask.shape if attention_mask is not None else 'None'}, labels shape: {labels.shape}")
            print(f"  Batch IDs: {batch.get('ids_debug', 'N/A')}")
            import traceback
            traceback.print_exc()
            optimizer.zero_grad(set_to_none=True) # Ensure grads are cleared
            num_nan_batches_epoch +=1 # Count as a problematic batch
            continue


    avg_epoch_loss = epoch_loss / num_valid_batches_epoch if num_valid_batches_epoch > 0 else float('nan')
    print(f"Epoch {epoch+1}/{NUM_EPOCHS} - Avg Loss: {avg_epoch_loss:.4f}, Valid Batches: {num_valid_batches_epoch}, NaN Batches: {num_nan_batches_epoch}")

# --- 8. Saving the Model and Processor ---
if num_valid_batches_epoch > 0 and not np.isnan(avg_epoch_loss):
    print(f"\nSaving fine-tuned model and processor to {OUTPUT_DIR}...")
    model.save_pretrained(OUTPUT_DIR)
    processor.save_pretrained(OUTPUT_DIR)
    print("Training complete and model saved.")
else:
    print("\nSkipping model saving due to NaN losses or no valid batches during training.")
# Out:
# Using device: cuda
# Loading model, processor, and config for: facebook/wav2vec2-base-960h...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# --- Verifying Tokenizer and Model Config ---
# Model CTC Blank ID (model.config.pad_token_id): 0
# Processor Padding ID (processor.tokenizer.pad_token_id): 0
# Pad token IDs match. OK.
# Model inputs_to_logits_ratio: 320
# --- End Verification ---
#
# Loading LibriSpeech dataset...
# Using 300 samples for training.
#
# --- Sanity Checking Dataloader Output ---
# Total samples in original subset: 300
# Effective samples after AudioDataset filtering: 300
#
# Sanity Check Batch 0:
#   Input values shape: torch.Size([2, 252880])
#   Attention mask shape: torch.Size([2, 252880])
#   Labels shape: torch.Size([2, 271])
#   Sample 0 Decoded Labels (first 50 chars): 'SO MATHEW AND I HAVE TALKED IT OVER OF AND ON EVER'
#   Sample 0 CTC check: WF_len=230800, ExpLogits=721, Lbl_len=271. Valid: True
# --- End Sanity Checking ---
#
# Starting training...
# Epoch 1/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 1, Batch 1. IDs: ['103-1240-40', '1040-133433-70']
#   Input values: min=-1.45e+01, max=1.27e+01, mean=-1.18e-09
#   Logits: min=-3.24e+01, max=1.20e+01, mean=-3.35e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 2. IDs: ['1034-121119-25', '1040-133433-15']
#   Input values: min=-1.60e+01, max=1.66e+01, mean=7.39e-09
#   Logits: min=-2.79e+01, max=7.67e+00, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 3. IDs: ['1034-121119-64', '1040-133433-6']
#   Input values: min=-1.02e+01, max=1.16e+01, mean=4.27e-09
#   Logits: min=-3.33e+01, max=1.39e+01, mean=-3.60e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 17. IDs: ['1069-133699-8', '1034-121119-93']
#   Input values: min=-1.03e+01, max=9.04e+00, mean=-4.06e-09
#   Logits: min=-2.59e+01, max=9.51e+00, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 19. IDs: ['103-1241-28', '1034-121119-39']
#   Input values: min=-1.47e+01, max=1.12e+01, mean=4.60e-11
#   Logits: min=-5.85e+01, max=1.61e+01, mean=-3.84e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 20. IDs: ['1040-133433-69', '1034-121119-2']
#   Input values: min=-1.11e+01, max=1.05e+01, mean=4.57e-09
#   Logits: min=-2.80e+01, max=1.16e+01, mean=-2.99e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 21. IDs: ['1069-133699-9', '1034-121119-47']
#   Input values: min=-1.01e+01, max=8.79e+00, mean=4.32e-09
#   Logits: min=-3.00e+01, max=1.07e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 25. IDs: ['1034-121119-46', '103-1241-36']
#   Input values: min=-1.26e+01, max=8.26e+00, mean=7.20e-10
#   Logits: min=-2.81e+01, max=8.78e+00, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 27. IDs: ['1034-121119-33', '1034-121119-90']
#   Input values: min=-8.68e+00, max=9.23e+00, mean=1.59e-09
#   Logits: min=-2.92e+01, max=1.13e+01, mean=-2.87e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 32. IDs: ['103-1240-36', '1034-121119-35']
#   Input values: min=-1.21e+01, max=9.01e+00, mean=-9.05e-10
#   Logits: min=-2.38e+01, max=8.89e+00, mean=-2.67e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 34. IDs: ['1034-121119-17', '103-1241-17']
#   Input values: min=-1.86e+01, max=1.10e+01, mean=-4.97e-09
#   Logits: min=-2.82e+01, max=9.50e+00, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 41. IDs: ['1034-121119-83', '103-1241-25']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=1.23e-09
#   Logits: min=-2.89e+01, max=9.53e+00, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 43. IDs: ['103-1241-31', '1034-121119-9']
#   Input values: min=-2.39e+01, max=1.85e+01, mean=6.15e-09
#   Logits: min=-2.65e+01, max=9.21e+00, mean=-2.78e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 47. IDs: ['1040-133433-30', '1040-133433-17']
#   Input values: min=-1.10e+01, max=1.14e+01, mean=-8.25e-10
#   Logits: min=-3.00e+01, max=1.26e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 48. IDs: ['103-1241-29', '1040-133433-13']
#   Input values: min=-1.58e+01, max=1.88e+01, mean=1.41e-09
#   Logits: min=-2.77e+01, max=1.04e+01, mean=-2.95e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 49. IDs: ['1034-121119-68', '103-1240-49']
#   Input values: min=-1.82e+01, max=1.53e+01, mean=2.00e-09
#   Logits: min=-5.65e+01, max=1.74e+01, mean=-3.41e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 52. IDs: ['1040-133433-19', '103-1240-20']
#   Input values: min=-1.42e+01, max=1.70e+01, mean=6.04e-10
#   Logits: min=-3.05e+01, max=1.02e+01, mean=-3.04e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 55. IDs: ['1034-121119-91', '1034-121119-0']
#   Input values: min=-1.21e+01, max=1.27e+01, mean=6.14e-10
#   Logits: min=-3.93e+01, max=1.80e+01, mean=-4.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 56. IDs: ['1040-133433-9', '1040-133433-64']
#   Input values: min=-1.03e+01, max=1.18e+01, mean=6.13e-10
#   Logits: min=-5.46e+01, max=1.61e+01, mean=-2.84e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 58. IDs: ['1040-133433-54', '1069-133699-0']
#   Input values: min=-9.10e+00, max=1.31e+01, mean=2.71e-09
#   Logits: min=-2.35e+01, max=7.53e+00, mean=-2.77e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 63. IDs: ['1040-133433-66', '103-1241-23']
#   Input values: min=-3.26e+01, max=1.92e+01, mean=3.30e-09
#   Logits: min=-2.72e+01, max=9.33e+00, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 70. IDs: ['1034-121119-55', '1034-121119-60']
#   Input values: min=-1.61e+01, max=1.05e+01, mean=1.03e-08
#   Logits: min=-2.98e+01, max=9.06e+00, mean=-2.89e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 79. IDs: ['103-1240-1', '1040-133433-78']
#   Input values: min=-1.63e+01, max=1.14e+01, mean=-2.58e-10
#   Logits: min=-3.05e+01, max=1.01e+01, mean=-2.84e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 82. IDs: ['1034-121119-10', '103-1240-5']
#   Input values: min=-1.27e+01, max=7.69e+00, mean=2.83e-10
#   Logits: min=-2.85e+01, max=1.08e+01, mean=-2.84e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 85. IDs: ['1034-121119-38', '1040-133433-65']
#   Input values: min=-1.10e+01, max=1.74e+01, mean=4.67e-10
#   Logits: min=-3.37e+01, max=1.54e+01, mean=-3.36e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 87. IDs: ['1034-121119-41', '1034-121119-58']
#   Input values: min=-8.97e+00, max=1.08e+01, mean=2.30e-10
#   Logits: min=-3.08e+01, max=1.32e+01, mean=-3.28e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 89. IDs: ['1040-133433-22', '1034-121119-54']
#   Input values: min=-1.54e+01, max=1.57e+01, mean=-1.07e-09
#   Logits: min=-2.70e+01, max=1.04e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 90. IDs: ['103-1241-19', '1034-121119-50']
#   Input values: min=-1.45e+01, max=1.22e+01, mean=-7.41e-09
#   Logits: min=-2.94e+01, max=1.10e+01, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 95. IDs: ['1040-133433-2', '1040-133433-21']
#   Input values: min=-1.32e+01, max=1.58e+01, mean=-1.16e-09
#   Logits: min=-3.14e+01, max=1.27e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 98. IDs: ['103-1240-16', '1040-133433-48']
#   Input values: min=-2.53e+01, max=1.68e+01, mean=3.68e-09
#   Logits: min=-3.00e+01, max=1.10e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 104. IDs: ['1034-121119-76', '1040-133433-63']
#   Input values: min=-1.60e+01, max=1.46e+01, mean=3.98e-10
#   Logits: min=-3.30e+01, max=1.59e+01, mean=-3.38e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 110. IDs: ['1034-121119-88', '1034-121119-77']
#   Input values: min=-7.39e+00, max=7.29e+00, mean=-1.44e-09
#   Logits: min=-2.65e+01, max=1.04e+01, mean=-2.85e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 116. IDs: ['103-1241-16', '103-1240-15']
#   Input values: min=-1.56e+01, max=8.52e+00, mean=3.39e-09
#   Logits: min=-5.91e+01, max=1.59e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 121. IDs: ['103-1241-18', '1034-121119-80']
#   Input values: min=-2.08e+01, max=1.57e+01, mean=7.83e-10
#   Logits: min=-2.77e+01, max=9.58e+00, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 124. IDs: ['1034-121119-61', '1040-133433-38']
#   Input values: min=-9.66e+00, max=1.31e+01, mean=2.92e-09
#   Logits: min=-2.82e+01, max=1.05e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 125. IDs: ['1034-121119-89', '1034-121119-48']
#   Input values: min=-1.13e+01, max=1.11e+01, mean=2.39e-09
#   Logits: min=-5.17e+01, max=1.50e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 130. IDs: ['103-1241-27', '1034-121119-92']
#   Input values: min=-1.82e+01, max=1.01e+01, mean=-1.38e-09
#   Logits: min=-2.67e+01, max=9.30e+00, mean=-2.87e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 133. IDs: ['1034-121119-45', '1034-121119-67']
#   Input values: min=-1.09e+01, max=1.18e+01, mean=2.59e-09
#   Logits: min=-3.09e+01, max=1.56e+01, mean=-3.08e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 135. IDs: ['1034-121119-21', '1034-121119-19']
#   Input values: min=-9.63e+00, max=8.74e+00, mean=7.74e-09
#   Logits: min=-2.73e+01, max=9.06e+00, mean=-2.87e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 1, Batch 141. IDs: ['103-1240-53', '1040-133433-18']
#   Input values: min=-1.64e+01, max=1.80e+01, mean=2.64e-09
#   Logits: min=-3.13e+01, max=1.28e+01, mean=-3.32e+00, has_nan=False
# Epoch 1/5 - Avg Loss: 907.5570, Valid Batches: 110, NaN Batches: 40
# Epoch 2/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 2, Batch 0. IDs: ['103-1240-42', '1034-121119-24']
#   Input values: min=-1.41e+01, max=8.33e+00, mean=4.47e-09
#   Logits: min=-2.81e+01, max=1.10e+01, mean=-3.21e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 1. IDs: ['1040-133433-48', '1040-133433-45']
#   Input values: min=-1.03e+01, max=1.68e+01, mean=-9.22e-12
#   Logits: min=-5.69e+01, max=1.72e+01, mean=-3.38e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 2. IDs: ['1034-121119-26', '1040-133433-32']
#   Input values: min=-9.51e+00, max=1.81e+01, mean=2.41e-09
#   Logits: min=-2.84e+01, max=9.31e+00, mean=-3.00e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 10. IDs: ['1034-121119-9', '103-1240-37']
#   Input values: min=-2.37e+01, max=2.33e+01, mean=-7.72e-10
#   Logits: min=-2.88e+01, max=1.10e+01, mean=-3.08e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 16. IDs: ['1040-133433-65', '1034-121119-88']
#   Input values: min=-1.10e+01, max=1.74e+01, mean=4.37e-10
#   Logits: min=-2.75e+01, max=9.33e+00, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 28. IDs: ['1034-121119-16', '1040-133433-79']
#   Input values: min=-1.17e+01, max=1.23e+01, mean=9.29e-09
#   Logits: min=-2.86e+01, max=9.69e+00, mean=-2.99e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 30. IDs: ['103-1241-19', '1040-133433-52']
#   Input values: min=-1.45e+01, max=1.25e+01, mean=-8.77e-10
#   Logits: min=-2.63e+01, max=8.33e+00, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 37. IDs: ['103-1240-21', '1040-133433-19']
#   Input values: min=-1.54e+01, max=1.70e+01, mean=9.68e-10
#   Logits: min=-2.80e+01, max=1.57e+01, mean=-3.04e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 39. IDs: ['103-1240-43', '1040-133433-37']
#   Input values: min=-1.80e+01, max=1.03e+01, mean=-1.78e-09
#   Logits: min=-2.97e+01, max=9.68e+00, mean=-2.87e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 42. IDs: ['1040-133433-24', '103-1241-21']
#   Input values: min=-1.59e+01, max=1.14e+01, mean=1.81e-09
#   Logits: min=-2.79e+01, max=9.97e+00, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 44. IDs: ['1034-121119-50', '1034-121119-18']
#   Input values: min=-8.25e+00, max=1.22e+01, mean=-7.82e-09
#   Logits: min=-2.66e+01, max=1.01e+01, mean=-2.98e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 46. IDs: ['1034-121119-42', '1034-121119-11']
#   Input values: min=-1.05e+01, max=1.24e+01, mean=6.00e-09
#   Logits: min=-3.53e+01, max=1.69e+01, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 61. IDs: ['1040-133433-15', '1034-121119-83']
#   Input values: min=-1.60e+01, max=1.66e+01, mean=2.30e-09
#   Logits: min=-2.80e+01, max=1.06e+01, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 66. IDs: ['1034-121119-84', '1034-121119-58']
#   Input values: min=-9.42e+00, max=1.08e+01, mean=9.19e-10
#   Logits: min=-2.91e+01, max=1.20e+01, mean=-3.00e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 68. IDs: ['103-1241-18', '1040-133433-69']
#   Input values: min=-2.08e+01, max=1.57e+01, mean=2.25e-09
#   Logits: min=-2.88e+01, max=1.18e+01, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 72. IDs: ['1034-121119-75', '1040-133433-16']
#   Input values: min=-1.22e+01, max=1.34e+01, mean=-5.74e-09
#   Logits: min=-2.71e+01, max=1.05e+01, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 74. IDs: ['1034-121119-40', '1034-121119-80']
#   Input values: min=-1.26e+01, max=1.23e+01, mean=2.13e-09
#   Logits: min=-2.88e+01, max=1.33e+01, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 78. IDs: ['1040-133433-6', '1040-133433-58']
#   Input values: min=-1.04e+01, max=1.81e+01, mean=1.45e-10
#   Logits: min=-2.60e+01, max=8.78e+00, mean=-2.89e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 80. IDs: ['1040-133433-70', '103-1240-45']
#   Input values: min=-1.56e+01, max=1.27e+01, mean=1.09e-09
#   Logits: min=-3.05e+01, max=1.16e+01, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 86. IDs: ['1040-133433-66', '103-1240-38']
#   Input values: min=-1.19e+01, max=8.74e+00, mean=2.17e-10
#   Logits: min=-3.29e+01, max=1.44e+01, mean=-2.86e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 88. IDs: ['1040-133433-74', '1040-133433-51']
#   Input values: min=-1.44e+01, max=1.93e+01, mean=2.75e-09
#   Logits: min=-3.21e+01, max=1.19e+01, mean=-3.46e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 90. IDs: ['103-1240-23', '1034-121119-76']
#   Input values: min=-1.61e+01, max=1.43e+01, mean=-2.15e-09
#   Logits: min=-3.10e+01, max=1.56e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 93. IDs: ['103-1240-56', '1034-121119-22']
#   Input values: min=-1.08e+01, max=9.18e+00, mean=5.16e-10
#   Logits: min=-5.61e+01, max=1.60e+01, mean=-3.12e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 95. IDs: ['103-1240-12', '1040-133433-13']
#   Input values: min=-1.95e+01, max=1.88e+01, mean=2.32e-09
#   Logits: min=-3.26e+01, max=1.49e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 98. IDs: ['103-1240-15', '103-1240-35']
#   Input values: min=-1.56e+01, max=8.95e+00, mean=-1.78e-09
#   Logits: min=-2.97e+01, max=1.14e+01, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 101. IDs: ['1040-133433-64', '1034-121119-70']
#   Input values: min=-9.87e+00, max=1.18e+01, mean=-3.83e-09
#   Logits: min=-3.18e+01, max=1.24e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 103. IDs: ['103-1241-27', '1034-121119-90']
#   Input values: min=-1.82e+01, max=1.01e+01, mean=1.20e-10
#   Logits: min=-6.46e+01, max=1.87e+01, mean=-3.37e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 111. IDs: ['1034-121119-17', '1040-133433-80']
#   Input values: min=-1.61e+01, max=2.32e+01, mean=-3.07e-09
#   Logits: min=-5.88e+01, max=1.74e+01, mean=-3.53e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 114. IDs: ['1034-121119-35', '1034-121119-15']
#   Input values: min=-9.23e+00, max=8.66e+00, mean=-4.47e-09
#   Logits: min=-2.97e+01, max=1.14e+01, mean=-3.00e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 116. IDs: ['1040-133433-21', '1034-121119-19']
#   Input values: min=-9.63e+00, max=8.74e+00, mean=7.31e-09
#   Logits: min=-3.43e+01, max=1.52e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 119. IDs: ['1040-133433-9', '1034-121119-10']
#   Input values: min=-1.03e+01, max=1.05e+01, mean=1.55e-09
#   Logits: min=-2.80e+01, max=1.04e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 125. IDs: ['1034-121119-93', '103-1240-41']
#   Input values: min=-1.46e+01, max=1.03e+01, mean=-1.47e-09
#   Logits: min=-2.91e+01, max=1.12e+01, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 126. IDs: ['103-1241-38', '1034-121119-0']
#   Input values: min=-1.80e+01, max=1.27e+01, mean=-6.85e-09
#   Logits: min=-3.15e+01, max=1.21e+01, mean=-3.35e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 132. IDs: ['1034-121119-54', '103-1241-0']
#   Input values: min=-1.87e+01, max=9.59e+00, mean=-3.73e-10
#   Logits: min=-2.90e+01, max=9.77e+00, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 138. IDs: ['103-1240-6', '1034-121119-21']
#   Input values: min=-1.29e+01, max=7.42e+00, mean=1.77e-09
#   Logits: min=-3.03e+01, max=9.49e+00, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 141. IDs: ['1040-133433-31', '1034-121119-67']
#   Input values: min=-1.01e+01, max=1.71e+01, mean=1.48e-09
#   Logits: min=-2.89e+01, max=1.07e+01, mean=-2.78e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 143. IDs: ['1040-133433-14', '1034-121119-12']
#   Input values: min=-1.39e+01, max=1.57e+01, mean=1.72e-09
#   Logits: min=-5.71e+01, max=1.54e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 2, Batch 146. IDs: ['1034-121119-46', '103-1240-31']
#   Input values: min=-1.19e+01, max=8.74e+00, mean=1.09e-09
#   Logits: min=-2.75e+01, max=8.65e+00, mean=-2.85e+00, has_nan=False
# Epoch 2/5 - Avg Loss: 816.7514, Valid Batches: 112, NaN Batches: 38
# Epoch 3/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 3, Batch 2. IDs: ['103-1240-19', '1040-133433-6']
#   Input values: min=-1.86e+01, max=1.29e+01, mean=5.49e-10
#   Logits: min=-5.27e+01, max=1.70e+01, mean=-3.33e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 5. IDs: ['1040-133433-78', '103-1240-5']
#   Input values: min=-1.27e+01, max=1.14e+01, mean=-7.42e-10
#   Logits: min=-2.92e+01, max=9.71e+00, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 16. IDs: ['1040-133433-13', '1040-133433-31']
#   Input values: min=-1.58e+01, max=1.88e+01, mean=1.80e-09
#   Logits: min=-3.03e+01, max=1.09e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 17. IDs: ['1034-121119-24', '1034-121119-64']
#   Input values: min=-1.02e+01, max=1.16e+01, mean=4.05e-09
#   Logits: min=-3.08e+01, max=1.14e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 19. IDs: ['103-1240-32', '1040-133433-19']
#   Input values: min=-2.09e+01, max=1.70e+01, mean=-1.32e-09
#   Logits: min=-6.47e+01, max=1.74e+01, mean=-3.73e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 21. IDs: ['1034-121119-18', '1069-133699-10']
#   Input values: min=-1.21e+01, max=1.13e+01, mean=4.88e-10
#   Logits: min=-3.10e+01, max=1.08e+01, mean=-2.96e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 22. IDs: ['1034-121119-22', '1040-133433-79']
#   Input values: min=-1.17e+01, max=1.23e+01, mean=-3.98e-09
#   Logits: min=-2.97e+01, max=9.40e+00, mean=-2.99e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 26. IDs: ['1034-121119-84', '1040-133433-33']
#   Input values: min=-9.70e+00, max=1.36e+01, mean=4.19e-10
#   Logits: min=-2.92e+01, max=1.01e+01, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 37. IDs: ['103-1241-25', '1040-133433-34']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=5.94e-10
#   Logits: min=-2.84e+01, max=9.44e+00, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 38. IDs: ['1034-121119-93', '103-1240-36']
#   Input values: min=-1.21e+01, max=9.04e+00, mean=-2.96e-09
#   Logits: min=-2.50e+01, max=9.59e+00, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 42. IDs: ['103-1240-53', '1034-121119-67']
#   Input values: min=-1.64e+01, max=9.70e+00, mean=3.22e-09
#   Logits: min=-3.05e+01, max=1.21e+01, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 45. IDs: ['1040-133433-46', '103-1240-13']
#   Input values: min=-2.04e+01, max=1.13e+01, mean=-1.42e-09
#   Logits: min=-2.89e+01, max=9.76e+00, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 47. IDs: ['103-1241-13', '1040-133433-69']
#   Input values: min=-1.65e+01, max=1.05e+01, mean=1.31e-09
#   Logits: min=-2.77e+01, max=9.54e+00, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 51. IDs: ['1034-121119-80', '103-1241-28']
#   Input values: min=-1.47e+01, max=1.08e+01, mean=-8.43e-10
#   Logits: min=-2.80e+01, max=1.01e+01, mean=-2.81e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 53. IDs: ['1034-121119-62', '1034-121119-90']
#   Input values: min=-1.13e+01, max=1.24e+01, mean=3.18e-09
#   Logits: min=-2.84e+01, max=9.81e+00, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 54. IDs: ['1040-133433-15', '103-1240-31']
#   Input values: min=-1.60e+01, max=1.66e+01, mean=6.72e-10
#   Logits: min=-3.04e+01, max=1.22e+01, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 62. IDs: ['1034-121119-46', '1040-133433-36']
#   Input values: min=-1.27e+01, max=1.23e+01, mean=2.57e-09
#   Logits: min=-2.76e+01, max=1.12e+01, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 66. IDs: ['103-1240-30', '103-1241-19']
#   Input values: min=-1.46e+01, max=1.31e+01, mean=-5.58e-10
#   Logits: min=-3.35e+01, max=1.16e+01, mean=-3.06e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 76. IDs: ['1040-133433-4', '1034-121119-92']
#   Input values: min=-9.69e+00, max=1.28e+01, mean=2.07e-09
#   Logits: min=-2.93e+01, max=1.03e+01, mean=-2.86e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 77. IDs: ['103-1240-33', '1040-133433-24']
#   Input values: min=-1.69e+01, max=1.15e+01, mean=-1.31e-09
#   Logits: min=-5.63e+01, max=1.74e+01, mean=-3.28e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 78. IDs: ['103-1241-33', '1034-121119-9']
#   Input values: min=-1.65e+01, max=8.39e+00, mean=-1.09e-09
#   Logits: min=-3.06e+01, max=1.17e+01, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 79. IDs: ['103-1240-45', '103-1240-15']
#   Input values: min=-1.56e+01, max=9.44e+00, mean=1.51e-09
#   Logits: min=-3.40e+01, max=1.62e+01, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 80. IDs: ['1034-121119-59', '1040-133433-64']
#   Input values: min=-9.87e+00, max=1.18e+01, mean=2.72e-09
#   Logits: min=-3.11e+01, max=1.22e+01, mean=-3.06e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 91. IDs: ['1034-121119-25', '1069-133699-9']
#   Input values: min=-1.19e+01, max=8.58e+00, mean=8.05e-09
#   Logits: min=-3.33e+01, max=1.09e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 93. IDs: ['103-1241-34', '1040-133433-60']
#   Input values: min=-1.44e+01, max=2.08e+01, mean=-4.16e-10
#   Logits: min=-6.21e+01, max=1.81e+01, mean=-3.69e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 99. IDs: ['1034-121119-89', '103-1241-24']
#   Input values: min=-1.88e+01, max=1.28e+01, mean=-4.41e-09
#   Logits: min=-3.12e+01, max=1.39e+01, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 105. IDs: ['1034-121119-95', '1040-133433-70']
#   Input values: min=-8.39e+00, max=1.27e+01, mean=1.33e-08
#   Logits: min=-2.90e+01, max=1.23e+01, mean=-3.18e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 106. IDs: ['1034-121119-10', '1040-133433-66']
#   Input values: min=-8.71e+00, max=8.74e+00, mean=2.52e-09
#   Logits: min=-3.36e+01, max=1.38e+01, mean=-3.25e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 108. IDs: ['1034-121119-82', '103-1241-43']
#   Input values: min=-9.52e+00, max=9.33e+00, mean=-3.38e-09
#   Logits: min=-3.18e+01, max=1.25e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 117. IDs: ['103-1240-52', '1034-121119-68']
#   Input values: min=-1.85e+01, max=1.53e+01, mean=3.14e-09
#   Logits: min=-3.02e+01, max=1.10e+01, mean=-3.25e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 118. IDs: ['1034-121119-35', '103-1241-39']
#   Input values: min=-1.56e+01, max=1.00e+01, mean=-2.30e-09
#   Logits: min=-2.82e+01, max=1.42e+01, mean=-2.98e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 120. IDs: ['1069-133699-11', '1034-121119-76']
#   Input values: min=-9.42e+00, max=9.30e+00, mean=1.43e-09
#   Logits: min=-3.19e+01, max=1.16e+01, mean=-3.54e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 129. IDs: ['1034-121119-12', '103-1240-20']
#   Input values: min=-1.20e+01, max=8.70e+00, mean=6.13e-10
#   Logits: min=-2.79e+01, max=9.94e+00, mean=-2.89e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 133. IDs: ['1034-121119-41', '103-1241-21']
#   Input values: min=-1.59e+01, max=1.04e+01, mean=1.32e-09
#   Logits: min=-2.95e+01, max=9.69e+00, mean=-2.88e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 143. IDs: ['1034-121119-42', '1040-133433-3']
#   Input values: min=-1.01e+01, max=1.31e+01, mean=2.64e-09
#   Logits: min=-2.79e+01, max=8.64e+00, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 146. IDs: ['103-1241-16', '1040-133433-18']
#   Input values: min=-1.58e+01, max=1.80e+01, mean=2.45e-09
#   Logits: min=-3.23e+01, max=1.07e+01, mean=-2.95e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 148. IDs: ['1034-121119-77', '103-1240-4']
#   Input values: min=-1.30e+01, max=9.02e+00, mean=-1.35e-09
#   Logits: min=-2.88e+01, max=1.33e+01, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 3, Batch 149. IDs: ['103-1240-1', '1040-133433-38']
#   Input values: min=-1.63e+01, max=1.13e+01, mean=-1.27e-10
#   Logits: min=-3.27e+01, max=1.22e+01, mean=-3.03e+00, has_nan=False
# Epoch 3/5 - Avg Loss: 831.5419, Valid Batches: 112, NaN Batches: 38
# Epoch 4/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 4, Batch 0. IDs: ['1034-121119-5', '1040-133433-24']
#   Input values: min=-8.91e+00, max=1.14e+01, mean=1.60e-09
#   Logits: min=-4.38e+01, max=1.49e+01, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 4. IDs: ['1040-133433-27', '1034-121119-93']
#   Input values: min=-1.03e+01, max=1.28e+01, mean=1.23e-09
#   Logits: min=-5.87e+01, max=1.62e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 13. IDs: ['1040-133433-38', '1069-133699-8']
#   Input values: min=-8.73e+00, max=1.13e+01, mean=-2.80e-09
#   Logits: min=-2.57e+01, max=9.59e+00, mean=-2.88e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 14. IDs: ['103-1241-29', '1034-121119-0']
#   Input values: min=-1.21e+01, max=1.27e+01, mean=-5.22e-10
#   Logits: min=-2.90e+01, max=1.06e+01, mean=-2.88e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 17. IDs: ['103-1241-34', '1034-121119-4']
#   Input values: min=-1.44e+01, max=1.09e+01, mean=1.02e-09
#   Logits: min=-2.88e+01, max=1.04e+01, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 23. IDs: ['1034-121119-16', '1069-133699-9']
#   Input values: min=-8.09e+00, max=8.88e+00, mean=1.03e-08
#   Logits: min=-2.16e+01, max=5.46e+00, mean=-2.69e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 27. IDs: ['1040-133433-6', '1040-133433-29']
#   Input values: min=-1.95e+01, max=1.78e+01, mean=-2.84e-09
#   Logits: min=-5.36e+01, max=1.45e+01, mean=-3.17e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 31. IDs: ['103-1241-25', '103-1240-4']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=-1.52e-09
#   Logits: min=-4.96e+01, max=1.76e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 32. IDs: ['103-1240-33', '1034-121119-76']
#   Input values: min=-1.69e+01, max=1.15e+01, mean=-7.86e-10
#   Logits: min=-2.99e+01, max=1.16e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 36. IDs: ['1034-121119-18', '1069-133699-18']
#   Input values: min=-1.06e+01, max=1.06e+01, mean=1.20e-09
#   Logits: min=-2.82e+01, max=1.01e+01, mean=-2.84e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 43. IDs: ['1034-121119-89', '103-1240-44']
#   Input values: min=-2.02e+01, max=1.10e+01, mean=2.00e-09
#   Logits: min=-2.97e+01, max=1.10e+01, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 45. IDs: ['1034-121119-44', '103-1241-19']
#   Input values: min=-1.45e+01, max=1.16e+01, mean=-4.88e-09
#   Logits: min=-2.43e+01, max=7.69e+00, mean=-2.83e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 48. IDs: ['1034-121119-80', '103-1240-27']
#   Input values: min=-1.44e+01, max=9.08e+00, mean=3.47e-09
#   Logits: min=-2.93e+01, max=1.14e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 53. IDs: ['1034-121119-9', '103-1240-31']
#   Input values: min=-1.19e+01, max=8.74e+00, mean=1.70e-09
#   Logits: min=-5.45e+01, max=1.70e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 55. IDs: ['103-1241-41', '1034-121119-54']
#   Input values: min=-1.23e+01, max=1.25e+01, mean=1.05e-09
#   Logits: min=-3.37e+01, max=1.20e+01, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 61. IDs: ['103-1240-15', '1034-121119-43']
#   Input values: min=-1.56e+01, max=9.48e+00, mean=-9.60e-09
#   Logits: min=-2.85e+01, max=1.18e+01, mean=-2.84e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 62. IDs: ['1040-133433-64', '1040-133433-74']
#   Input values: min=-1.44e+01, max=1.93e+01, mean=1.21e-09
#   Logits: min=-2.98e+01, max=1.13e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 71. IDs: ['1034-121119-27', '1034-121119-10']
#   Input values: min=-1.21e+01, max=1.31e+01, mean=-7.78e-09
#   Logits: min=-2.01e+01, max=4.09e+00, mean=-2.60e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 74. IDs: ['103-1241-39', '1040-133433-60']
#   Input values: min=-1.56e+01, max=2.08e+01, mean=-1.94e-09
#   Logits: min=-3.11e+01, max=1.07e+01, mean=-3.06e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 75. IDs: ['103-1241-16', '1034-121119-22']
#   Input values: min=-1.51e+01, max=8.52e+00, mean=1.79e-09
#   Logits: min=-3.12e+01, max=1.09e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 83. IDs: ['1034-121119-88', '103-1241-38']
#   Input values: min=-1.80e+01, max=1.21e+01, mean=-5.31e-09
#   Logits: min=-2.88e+01, max=1.20e+01, mean=-2.88e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 91. IDs: ['1040-133433-17', '1034-121119-78']
#   Input values: min=-1.10e+01, max=1.14e+01, mean=7.32e-10
#   Logits: min=-2.91e+01, max=9.97e+00, mean=-2.83e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 94. IDs: ['103-1240-25', '1040-133433-70']
#   Input values: min=-1.19e+01, max=1.27e+01, mean=1.42e-09
#   Logits: min=-3.63e+01, max=1.32e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 98. IDs: ['1040-133433-45', '1040-133433-21']
#   Input values: min=-1.03e+01, max=1.21e+01, mean=-7.60e-10
#   Logits: min=-2.89e+01, max=9.86e+00, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 106. IDs: ['103-1241-12', '1040-133433-66']
#   Input values: min=-1.64e+01, max=9.56e+00, mean=1.04e-09
#   Logits: min=-3.00e+01, max=1.13e+01, mean=-3.10e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 107. IDs: ['1034-121119-29', '103-1241-1']
#   Input values: min=-2.78e+01, max=1.39e+01, mean=3.90e-09
#   Logits: min=-3.00e+01, max=1.08e+01, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 109. IDs: ['1034-121119-32', '1034-121119-36']
#   Input values: min=-1.05e+01, max=8.97e+00, mean=5.74e-09
#   Logits: min=-3.05e+01, max=9.61e+00, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 111. IDs: ['1034-121119-53', '1034-121119-38']
#   Input values: min=-9.64e+00, max=1.33e+01, mean=-2.44e-10
#   Logits: min=-5.72e+01, max=1.73e+01, mean=-3.41e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 115. IDs: ['1034-121119-33', '1040-133433-78']
#   Input values: min=-8.68e+00, max=1.14e+01, mean=5.93e-10
#   Logits: min=-5.52e+01, max=1.86e+01, mean=-3.14e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 118. IDs: ['1034-121119-11', '1034-121119-59']
#   Input values: min=-1.05e+01, max=1.24e+01, mean=7.53e-09
#   Logits: min=-3.00e+01, max=1.09e+01, mean=-3.22e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 120. IDs: ['103-1241-31', '1040-133433-54']
#   Input values: min=-2.39e+01, max=1.85e+01, mean=4.66e-09
#   Logits: min=-2.89e+01, max=1.13e+01, mean=-3.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 121. IDs: ['1040-133433-48', '103-1240-36']
#   Input values: min=-1.21e+01, max=1.68e+01, mean=-1.89e-09
#   Logits: min=-3.08e+01, max=1.19e+01, mean=-3.32e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 127. IDs: ['103-1241-13', '1034-121119-41']
#   Input values: min=-1.65e+01, max=9.82e+00, mean=-1.44e-10
#   Logits: min=-3.22e+01, max=1.03e+01, mean=-3.08e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 129. IDs: ['1034-121119-46', '1034-121119-24']
#   Input values: min=-7.51e+00, max=6.88e+00, mean=5.69e-10
#   Logits: min=-2.79e+01, max=1.01e+01, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 130. IDs: ['1034-121119-52', '1034-121119-90']
#   Input values: min=-1.17e+01, max=1.14e+01, mean=3.13e-09
#   Logits: min=-2.91e+01, max=1.00e+01, mean=-2.89e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 135. IDs: ['1040-133433-14', '1034-121119-26']
#   Input values: min=-1.39e+01, max=1.57e+01, mean=1.09e-09
#   Logits: min=-2.82e+01, max=1.05e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 138. IDs: ['1034-121119-65', '1040-133433-80']
#   Input values: min=-1.61e+01, max=2.32e+01, mean=3.99e-09
#   Logits: min=-2.96e+01, max=1.03e+01, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 139. IDs: ['1034-121119-67', '1034-121119-50']
#   Input values: min=-8.25e+00, max=1.22e+01, mean=-7.52e-09
#   Logits: min=-5.65e+01, max=1.73e+01, mean=-3.40e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 144. IDs: ['103-1241-36', '1040-133433-13']
#   Input values: min=-1.58e+01, max=1.88e+01, mean=1.11e-09
#   Logits: min=-3.09e+01, max=1.42e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 4, Batch 149. IDs: ['103-1240-38', '1034-121119-84']
#   Input values: min=-1.19e+01, max=9.69e+00, mean=-1.07e-09
#   Logits: min=-5.00e+01, max=1.66e+01, mean=-3.40e+00, has_nan=False
# Epoch 4/5 - Avg Loss: 804.1583, Valid Batches: 110, NaN Batches: 40
# Epoch 5/5:   0%|          | 0/150 [00:00<?, ?it/s]
# NaN/Inf loss detected! Epoch 5, Batch 7. IDs: ['1034-121119-91', '103-1241-19']
#   Input values: min=-1.45e+01, max=1.19e+01, mean=2.52e-09
#   Logits: min=-2.88e+01, max=1.01e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 13. IDs: ['1034-121119-6', '1034-121119-88']
#   Input values: min=-9.39e+00, max=8.50e+00, mean=-4.21e-09
#   Logits: min=-3.19e+01, max=1.06e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 15. IDs: ['103-1240-47', '1034-121119-59']
#   Input values: min=-1.45e+01, max=1.18e+01, mean=3.70e-09
#   Logits: min=-2.82e+01, max=1.19e+01, mean=-3.06e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 19. IDs: ['103-1241-16', '1040-133433-70']
#   Input values: min=-1.51e+01, max=1.27e+01, mean=2.45e-09
#   Logits: min=-2.85e+01, max=1.20e+01, mean=-2.94e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 21. IDs: ['1040-133433-26', '1040-133433-79']
#   Input values: min=-1.33e+01, max=1.47e+01, mean=-4.08e-09
#   Logits: min=-2.86e+01, max=1.10e+01, mean=-3.28e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 22. IDs: ['1034-121119-77', '103-1241-2']
#   Input values: min=-1.33e+01, max=8.61e+00, mean=6.13e-11
#   Logits: min=-3.21e+01, max=1.14e+01, mean=-3.01e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 28. IDs: ['103-1240-48', '1034-121119-86']
#   Input values: min=-1.49e+01, max=9.22e+00, mean=-2.54e-09
#   Logits: min=-2.94e+01, max=1.13e+01, mean=-3.19e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 29. IDs: ['1034-121119-23', '1034-121119-89']
#   Input values: min=-1.44e+01, max=1.10e+01, mean=1.74e-09
#   Logits: min=-5.69e+01, max=1.62e+01, mean=-3.23e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 30. IDs: ['1034-121119-93', '1040-133433-1']
#   Input values: min=-1.03e+01, max=1.26e+01, mean=-2.64e-09
#   Logits: min=-3.30e+01, max=1.07e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 32. IDs: ['103-1240-1', '1034-121119-54']
#   Input values: min=-1.63e+01, max=9.43e+00, mean=-1.64e-09
#   Logits: min=-3.26e+01, max=1.37e+01, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 34. IDs: ['103-1240-22', '1040-133433-24']
#   Input values: min=-1.35e+01, max=1.14e+01, mean=1.78e-09
#   Logits: min=-3.06e+01, max=1.12e+01, mean=-2.95e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 35. IDs: ['1040-133433-51', '1034-121119-19']
#   Input values: min=-1.33e+01, max=1.61e+01, mean=9.06e-09
#   Logits: min=-2.75e+01, max=1.00e+01, mean=-3.11e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 40. IDs: ['103-1240-49', '1034-121119-92']
#   Input values: min=-1.35e+01, max=9.11e+00, mean=-7.49e-10
#   Logits: min=-2.88e+01, max=1.26e+01, mean=-2.91e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 41. IDs: ['1040-133433-18', '103-1241-14']
#   Input values: min=-1.58e+01, max=1.80e+01, mean=1.35e-09
#   Logits: min=-2.87e+01, max=1.05e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 51. IDs: ['1034-121119-80', '103-1241-8']
#   Input values: min=-1.09e+01, max=8.91e+00, mean=-2.23e-09
#   Logits: min=-3.07e+01, max=1.01e+01, mean=-2.93e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 53. IDs: ['1040-133433-21', '1040-133433-45']
#   Input values: min=-1.03e+01, max=1.21e+01, mean=-5.00e-10
#   Logits: min=-2.67e+01, max=9.01e+00, mean=-2.97e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 59. IDs: ['103-1240-0', '1034-121119-90']
#   Input values: min=-1.13e+01, max=1.21e+01, mean=2.67e-09
#   Logits: min=-5.54e+01, max=1.69e+01, mean=-3.26e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 63. IDs: ['1040-133433-6', '103-1240-55']
#   Input values: min=-1.27e+01, max=1.02e+01, mean=1.09e-09
#   Logits: min=-2.82e+01, max=1.38e+01, mean=-2.88e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 67. IDs: ['103-1241-35', '1034-121119-76']
#   Input values: min=-1.73e+01, max=9.94e+00, mean=-1.99e-09
#   Logits: min=-3.17e+01, max=1.15e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 69. IDs: ['103-1240-16', '1034-121119-46']
#   Input values: min=-2.53e+01, max=1.38e+01, mean=3.21e-09
#   Logits: min=-2.84e+01, max=1.18e+01, mean=-2.95e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 72. IDs: ['1034-121119-41', '103-1240-17']
#   Input values: min=-1.53e+01, max=1.02e+01, mean=-1.67e-10
#   Logits: min=-2.95e+01, max=1.28e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 74. IDs: ['1034-121119-38', '1034-121119-33']
#   Input values: min=-9.59e+00, max=9.23e+00, mean=2.03e-09
#   Logits: min=-3.37e+01, max=1.22e+01, mean=-3.02e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 79. IDs: ['1034-121119-45', '1034-121119-9']
#   Input values: min=-1.09e+01, max=1.18e+01, mean=3.16e-09
#   Logits: min=-3.11e+01, max=1.07e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 83. IDs: ['1034-121119-8', '103-1240-57']
#   Input values: min=-1.04e+01, max=8.95e+00, mean=-7.59e-09
#   Logits: min=-3.04e+01, max=1.15e+01, mean=-3.16e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 85. IDs: ['1034-121119-44', '1040-133433-78']
#   Input values: min=-1.14e+01, max=1.15e+01, mean=-5.10e-09
#   Logits: min=-2.64e+01, max=8.93e+00, mean=-2.99e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 86. IDs: ['1069-133699-6', '1034-121119-36']
#   Input values: min=-8.83e+00, max=8.92e+00, mean=-1.40e-09
#   Logits: min=-3.81e+01, max=1.47e+01, mean=-3.05e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 89. IDs: ['1034-121119-84', '1040-133433-80']
#   Input values: min=-1.61e+01, max=2.32e+01, mean=2.01e-10
#   Logits: min=-3.20e+01, max=1.08e+01, mean=-3.06e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 95. IDs: ['1034-121119-0', '103-1240-2']
#   Input values: min=-1.35e+01, max=1.27e+01, mean=-1.20e-09
#   Logits: min=-3.24e+01, max=1.20e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 96. IDs: ['1040-133433-32', '103-1241-25']
#   Input values: min=-2.77e+01, max=2.10e+01, mean=2.12e-09
#   Logits: min=-2.80e+01, max=1.09e+01, mean=-2.90e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 100. IDs: ['103-1240-56', '1034-121119-10']
#   Input values: min=-1.08e+01, max=9.18e+00, mean=2.41e-09
#   Logits: min=-2.58e+01, max=1.08e+01, mean=-2.82e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 104. IDs: ['1069-133699-11', '1040-133433-66']
#   Input values: min=-7.87e+00, max=8.74e+00, mean=3.56e-10
#   Logits: min=-3.09e+01, max=1.15e+01, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 108. IDs: ['103-1240-15', '1034-121119-25']
#   Input values: min=-1.56e+01, max=8.58e+00, mean=8.02e-09
#   Logits: min=-2.55e+01, max=7.70e+00, mean=-2.77e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 110. IDs: ['1040-133433-48', '103-1240-21']
#   Input values: min=-1.54e+01, max=1.68e+01, mean=6.38e-10
#   Logits: min=-2.82e+01, max=1.02e+01, mean=-2.88e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 113. IDs: ['1040-133433-38', '1034-121119-5']
#   Input values: min=-8.91e+00, max=1.13e+01, mean=2.18e-09
#   Logits: min=-2.71e+01, max=8.98e+00, mean=-2.83e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 116. IDs: ['103-1240-52', '1034-121119-35']
#   Input values: min=-1.85e+01, max=1.13e+01, mean=1.52e-09
#   Logits: min=-2.62e+01, max=1.04e+01, mean=-2.72e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 126. IDs: ['1069-133699-9', '1034-121119-52']
#   Input values: min=-1.17e+01, max=1.14e+01, mean=3.17e-09
#   Logits: min=-2.85e+01, max=1.12e+01, mean=-2.92e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 136. IDs: ['103-1241-24', '1040-133433-15']
#   Input values: min=-1.88e+01, max=1.66e+01, mean=-4.29e-09
#   Logits: min=-3.08e+01, max=1.24e+01, mean=-3.15e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 137. IDs: ['1034-121119-22', '1040-133433-57']
#   Input values: min=-1.60e+01, max=2.66e+01, mean=-2.65e-09
#   Logits: min=-3.07e+01, max=1.16e+01, mean=-3.07e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 140. IDs: ['1034-121119-60', '103-1241-31']
#   Input values: min=-2.39e+01, max=1.85e+01, mean=1.02e-09
#   Logits: min=-3.05e+01, max=1.35e+01, mean=-3.38e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 141. IDs: ['103-1241-33', '1034-121119-24']
#   Input values: min=-1.65e+01, max=8.39e+00, mean=-1.61e-09
#   Logits: min=-3.09e+01, max=1.28e+01, mean=-3.43e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 143. IDs: ['1034-121119-26', '103-1241-7']
#   Input values: min=-1.90e+01, max=1.11e+01, mean=-4.63e-09
#   Logits: min=-3.38e+01, max=1.27e+01, mean=-3.09e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 145. IDs: ['103-1241-15', '1034-121119-67']
#   Input values: min=-1.21e+01, max=1.00e+01, mean=-8.25e-10
#   Logits: min=-3.21e+01, max=1.15e+01, mean=-3.04e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 146. IDs: ['1034-121119-48', '1034-121119-42']
#   Input values: min=-1.13e+01, max=1.11e+01, mean=1.84e-09
#   Logits: min=-2.94e+01, max=1.16e+01, mean=-3.03e+00, has_nan=False
#
# NaN/Inf loss detected! Epoch 5, Batch 148. IDs: ['1040-133433-64', '1040-133433-72']
#   Input values: min=-1.17e+01, max=1.85e+01, mean=4.28e-10
#   Logits: min=-2.77e+01, max=1.13e+01, mean=-3.16e+00, has_nan=False
# Epoch 5/5 - Avg Loss: 787.4517, Valid Batches: 106, NaN Batches: 44
#
# Saving fine-tuned model and processor to ./wav2vec2_librispeech_finetuned...
# Training complete and model saved.

# %%
# --- 9. Simple Inference Example ---
# Check for either pytorch_model.bin or model.safetensors
model_weights_name_bin = "pytorch_model.bin"
model_weights_name_sf = "model.safetensors" # Standard name for safetensors weights

model_path_bin = os.path.join(OUTPUT_DIR, model_weights_name_bin)
model_path_sf = os.path.join(OUTPUT_DIR, model_weights_name_sf)

if os.path.exists(model_path_bin) or os.path.exists(model_path_sf):
    print("\n--- Inference Example ---")
    try:
        # Wav2Vec2ForCTC.from_pretrained will automatically find the correct weights file
        model_inf = Wav2Vec2ForCTC.from_pretrained(OUTPUT_DIR).to(DEVICE)
        processor_inf = Wav2Vec2Processor.from_pretrained(OUTPUT_DIR)
        model_inf.eval()

        # Make sure there's at least one valid sample in the processed_dataset for inference
        # (or use the original `dataset` if that's preferred and handle None items)
        # Let's try to find the first valid item from processed_dataset for inference
        inference_sample_data = None
        """if len(processed_dataset) > 0: # Check if processed_dataset has items
            for i in range(len(processed_dataset)):
                a = 0
                sample_candidate = processed_dataset.torchaudio_dataset[i] # Get from original subset via processed_dataset
                # We need the original waveform and transcript for this example
                # The processed_dataset.__getitem__ returns processed values or None
                # So we access the underlying torchaudio_dataset item
                if sample_candidate and sample_candidate[2].strip(): # waveform, sr, utterance, ...
                    a+=1
                    waveform_orig, sr_orig, original_transcript, speaker_id, chapter_id, utterance_id = sample_candidate
                    inference_sample_data = sample_candidate
                    if a==5:
                      break"""
        print(len(processed_dataset))
        sample_candidate = test_dataset.torchaudio_dataset[567]
        waveform_orig, sr_orig, original_transcript, speaker_id, chapter_id, utterance_id = sample_candidate
        inference_sample_data = sample_candidate
        if inference_sample_data:
            waveform_orig, sr_orig, original_transcript, speaker_id, chapter_id, utterance_id = inference_sample_data
            print(f"\nOriginal transcript (ID: {speaker_id}-{chapter_id}-{utterance_id}):")
            print(original_transcript)

            # Resample if necessary
            target_sr_inf = processor_inf.feature_extractor.sampling_rate
            if sr_orig != target_sr_inf:
                resampler = torchaudio.transforms.Resample(orig_freq=sr_orig, new_freq=target_sr_inf)
                waveform_orig = resampler(waveform_orig)

            waveform_squeezed_orig = waveform_orig.squeeze(0)
            if waveform_squeezed_orig.ndim == 0: # Should not happen with LibriSpeech
                 raise ValueError("Waveform for inference became a scalar.")

            # Process for inference
            input_dict = processor_inf(
                waveform_squeezed_orig,
                return_tensors="pt",
                sampling_rate=target_sr_inf, # Use the processor's expected sampling rate
                padding=True # Padding might be good for single sample if model expects it
            )
            input_values_inf = input_dict.input_values.to(DEVICE)
            # Ensure attention_mask is passed if generated and model uses it
            attention_mask_inf = input_dict.attention_mask.to(DEVICE) if hasattr(input_dict, 'attention_mask') and input_dict.attention_mask is not None else None


            with torch.no_grad():
                logits_inf = model_inf(input_values_inf, attention_mask=attention_mask_inf).logits

            predicted_ids = torch.argmax(logits_inf, dim=-1)
            predicted_sentence = processor_inf.batch_decode(predicted_ids)[0]
            print(f"\nPredicted transcript:")
            print(predicted_sentence)
        else:
            print("Not enough valid samples in the dataset to run inference example.")
            print(f"(Checked {len(processed_dataset)} entries in processed_dataset for a suitable sample).")

    except Exception as e:
        print(f"Error during inference example: {e}")
        import traceback
        traceback.print_exc()
else:
    print(f"\nInference example skipped as model weights ('{model_weights_name_bin}' or '{model_weights_name_sf}') not found in {OUTPUT_DIR}.")

print("\nScript finished.")
# Out:
# --- Inference Example ---
# 300
#
# Original transcript (ID: 1088-134315-19):
# HE RANG THE BELL THIS TIME FOR HIS VALET FISHER HE SAID I AM EXPECTING A VISIT FROM A GENTLEMAN NAMED GATHERCOLE A ONE ARMED GENTLEMAN WHOM YOU MUST LOOK AFTER IF HE COMES
#
# Predicted transcript:
# HE RANG THE BELL THIS TIME FOR HIS VALET FISHER HE SAID I AM EXPECTING A VISIT FROM A GENTLEMAN NAMED GATHERCO A ONE ARMED GENTLEMAN WHOM YOU MUST LOOK AFTER IF HE COMES
#
# Script finished.
